# %%
## Full backend analysis for the CREEDS and L1000 dataset 
import os
import pandas as pd
from pandas.compat import StringIO
import numpy as np
from numpy import loadtxt
import sys
import json
from pprint import pprint
import objectpath
import csv
import re
import matplotlib.pyplot as plt
import json, requests
from pprint import pprint
import itertools
import scipy
from scipy.spatial import distance
from sklearn.metrics.pairwise import pairwise_distances
from clustergrammer_widget import *
def get_geneset(df, indexer):
    df_ = df.loc[indexer, :]
    return list(df_[df_ == 1].index)

# %%
### L1000 PRELOAD DATA DRUG CARD
with open ("L1000_up_lookup.json", 'r') as f:
    L1000_up_lookup = json.load(f)

with open ("L1000_down_lookup.json", 'r') as f:
    L1000_down_lookup = json.load(f)
    
metadata = pd.read_csv("L1000_metadata.csv")

### L1000 DRUG CARD DRUG INPUT
DrOI = "tretinoin" ## this will be the user input 

DrOI_df = metadata[metadata["pert_desc"] == DrOI]
DrOI_pert_ids = list(DrOI_df["pert_id"])

DrOI_up_signatures = {k: L1000_up_lookup[k] for k in (DrOI_pert_ids)}
DrOI_up_no_perts = {k: v for d in DrOI_up_signatures.values() for k, v in d.items()}
DrOI_up_drug_sigs = list(DrOI_up_no_perts.keys())

DrOI_down_signatures = {k: L1000_down_lookup[k] for k in (DrOI_pert_ids)}
DrOI_down_no_perts = {k: v for d in DrOI_down_signatures.values() for k, v in d.items()}
DrOI_down_drug_sigs = list(DrOI_down_no_perts.keys())

DrOI_all_sigs = set(DrOI_up_drug_sigs) & set (DrOI_down_drug_sigs)

for a in DrOI_all_sigs:
    L1000_up_json_file = DrOI_up_no_perts[a]
    L1000_down_json_file = DrOI_down_no_perts[a]
    with open(a + "_L1000_up_sig.json", "w") as f:
        #json.dump(L1000_up_json_file, f)
    with open(a + "_L1000_down_sig.json", "w") as f:
        #json.dump(L1000_down_json_file, f)

# %%
DrOI_df
# Out:
#                                                rid  SCS_centered_by_batch  \
# 86     ASG001_MCF7_24H:BRD-K71879491-001-17-6:0.08                 0.0000
# 87      ASG001_MCF7_24H:BRD-K71879491-001-17-6:0.4                 0.0000
# 88       ASG001_MCF7_24H:BRD-K71879491-001-17-6:10                 0.0000
# 89        ASG001_MCF7_24H:BRD-K71879491-001-17-6:2                 0.0000
# 162     ASG001_MCF7_6H:BRD-K71879491-001-17-6:0.08                 0.0000
# 163      ASG001_MCF7_6H:BRD-K71879491-001-17-6:0.4                 0.0000
# 164       ASG001_MCF7_6H:BRD-K71879491-001-17-6:10                 0.0000
# 165        ASG001_MCF7_6H:BRD-K71879491-001-17-6:2                 0.0000
# 220      ASG001_PC3_24H:BRD-K71879491-001-17-6:0.4                 0.0049
# 221       ASG001_PC3_24H:BRD-K71879491-001-17-6:10                 0.0000
# 222        ASG001_PC3_24H:BRD-K71879491-001-17-6:2                 0.0014
# 265       ASG001_PC3_6H:BRD-K71879491-001-17-6:0.4                 0.0214
# 266        ASG001_PC3_6H:BRD-K71879491-001-17-6:10                 0.0344
# 22687     CPC014_A375_6H:BRD-K71879491-001-22-6:10                 0.0168
# 23213     CPC014_ASC_24H:BRD-K71879491-001-22-6:10                 0.0007
# 23387     CPC014_HA1E_6H:BRD-K71879491-001-22-6:10                 0.0098
# 23766    CPC014_HEPG2_6H:BRD-K71879491-001-22-6:10                 0.0070
# 23980     CPC014_HT29_6H:BRD-K71879491-001-22-6:10                 0.0000
# 24170    CPC014_MCF7_24H:BRD-K71879491-001-22-6:10                 0.0000
# 24384     CPC014_MCF7_6H:BRD-K71879491-001-22-6:10                 0.0000
# 24799     CPC014_PC3_24H:BRD-K71879491-001-22-6:10                 0.0000
# 25001      CPC014_PC3_6H:BRD-K71879491-001-22-6:10                 0.0030
# 25146     CPC014_PHH_24H:BRD-K71879491-001-22-6:10                 0.0168
# 25316     CPC014_SKB_24H:BRD-K71879491-001-22-6:10                 0.0000
# 25523    CPC014_VCAP_24H:BRD-K71879491-001-22-6:10                 0.0000
# 25726     CPC014_VCAP_6H:BRD-K71879491-001-22-6:10                 0.0215
# 35204     ERG005_VCAP_24H:BRD-K71879491-001-17-6:1                 0.0000
# 35205    ERG005_VCAP_24H:BRD-K71879491-001-17-6:20                 0.0000
# 35206     ERG005_VCAP_24H:BRD-K71879491-001-17-6:5                 0.0000
# 35254     ERG005_VCAP_48H:BRD-K71879491-001-17-6:1                 0.0000
# 35255    ERG005_VCAP_48H:BRD-K71879491-001-17-6:20                 0.0000
# 35256     ERG005_VCAP_48H:BRD-K71879491-001-17-6:5                 0.0000
# 35308      ERG005_VCAP_6H:BRD-K71879491-001-17-6:1                 0.0000
# 35309     ERG005_VCAP_6H:BRD-K71879491-001-17-6:20                 0.0000
# 35310      ERG005_VCAP_6H:BRD-K71879491-001-17-6:5                 0.0000
#
#                  batch cell_id  mean_cosine_dist_centered_by_batch  pert_desc  \
# 86     ASG001_MCF7_24H    MCF7                                 NaN  tretinoin
# 87     ASG001_MCF7_24H    MCF7                                 NaN  tretinoin
# 88     ASG001_MCF7_24H    MCF7                                 NaN  tretinoin
# 89     ASG001_MCF7_24H    MCF7                                 NaN  tretinoin
# 162     ASG001_MCF7_6H    MCF7                                 NaN  tretinoin
# 163     ASG001_MCF7_6H    MCF7                                 NaN  tretinoin
# 164     ASG001_MCF7_6H    MCF7                                 NaN  tretinoin
# 165     ASG001_MCF7_6H    MCF7                                 NaN  tretinoin
# 220     ASG001_PC3_24H     PC3                            0.911756  tretinoin
# 221     ASG001_PC3_24H     PC3                            0.778611  tretinoin
# 222     ASG001_PC3_24H     PC3                            0.897770  tretinoin
# 265      ASG001_PC3_6H     PC3                            0.892500  tretinoin
# 266      ASG001_PC3_6H     PC3                            0.912114  tretinoin
# 22687   CPC014_A375_6H    A375                            0.899472  tretinoin
# 23213   CPC014_ASC_24H     ASC                            0.865293  tretinoin
# 23387   CPC014_HA1E_6H    HA1E                            0.933067  tretinoin
# 23766  CPC014_HEPG2_6H   HEPG2                            0.925271  tretinoin
# 23980   CPC014_HT29_6H    HT29                            0.883530  tretinoin
# 24170  CPC014_MCF7_24H    MCF7                            0.754638  tretinoin
# 24384   CPC014_MCF7_6H    MCF7                            0.797029  tretinoin
# 24799   CPC014_PC3_24H     PC3                            0.917934  tretinoin
# 25001    CPC014_PC3_6H     PC3                            0.930169  tretinoin
# 25146   CPC014_PHH_24H     PHH                            0.958967  tretinoin
# 25316   CPC014_SKB_24H     SKB                            0.884735  tretinoin
# 25523  CPC014_VCAP_24H    VCAP                            0.888441  tretinoin
# 25726   CPC014_VCAP_6H    VCAP                            0.970076  tretinoin
# 35204  ERG005_VCAP_24H    VCAP                                 NaN  tretinoin
# 35205  ERG005_VCAP_24H    VCAP                                 NaN  tretinoin
# 35206  ERG005_VCAP_24H    VCAP                                 NaN  tretinoin
# 35254  ERG005_VCAP_48H    VCAP                                 NaN  tretinoin
# 35255  ERG005_VCAP_48H    VCAP                                 NaN  tretinoin
# 35256  ERG005_VCAP_48H    VCAP                                 NaN  tretinoin
# 35308   ERG005_VCAP_6H    VCAP                                 NaN  tretinoin
# 35309   ERG005_VCAP_6H    VCAP                                 NaN  tretinoin
# 35310   ERG005_VCAP_6H    VCAP                                 NaN  tretinoin
#
#        pert_dose        pert_id  pert_time
# 86          0.08  BRD-K71879491       24.0
# 87          0.40  BRD-K71879491       24.0
# 88         10.00  BRD-K71879491       24.0
# 89          2.00  BRD-K71879491       24.0
# 162         0.08  BRD-K71879491        6.0
# 163         0.40  BRD-K71879491        6.0
# 164        10.00  BRD-K71879491        6.0
# 165         2.00  BRD-K71879491        6.0
# 220         0.40  BRD-K71879491       24.0
# 221        10.00  BRD-K71879491       24.0
# 222         2.00  BRD-K71879491       24.0
# 265         0.40  BRD-K71879491        6.0
# 266        10.00  BRD-K71879491        6.0
# 22687      10.00  BRD-K71879491        6.0
# 23213      10.00  BRD-K71879491       24.0
# 23387      10.00  BRD-K71879491        6.0
# 23766      10.00  BRD-K71879491        6.0
# 23980      10.00  BRD-K71879491        6.0
# 24170      10.00  BRD-K71879491       24.0
# 24384      10.00  BRD-K71879491        6.0
# 24799      10.00  BRD-K71879491       24.0
# 25001      10.00  BRD-K71879491        6.0
# 25146      10.00  BRD-K71879491       24.0
# 25316      10.00  BRD-K71879491       24.0
# 25523      10.00  BRD-K71879491       24.0
# 25726      10.00  BRD-K71879491        6.0
# 35204       1.00  BRD-K71879491       24.0
# 35205      20.00  BRD-K71879491       24.0
# 35206       5.00  BRD-K71879491       24.0
# 35254       1.00  BRD-K71879491       48.0
# 35255      20.00  BRD-K71879491       48.0
# 35256       5.00  BRD-K71879491       48.0
# 35308       1.00  BRD-K71879491        6.0
# 35309      20.00  BRD-K71879491        6.0
# 35310       5.00  BRD-K71879491        6.0

# %%
######################################################################################################

# %%
# load in the EMR Data (filtered > 200 in R code [Drug_diagnosis_test_code.R])
EMR_data = pd.read_csv("EMR_greater_200.csv")
## subset EMR data by the DOI and/or DrOI
EMR_data_df = pd.DataFrame(EMR_data)
#EMR_data
EMR_data_df.drop(EMR_data_df.columns[[0]], axis = 1, inplace = True) # remove the unecessary columns
#EMR_data_df

# implement the search from ICD9-do_id from the manual conversion
icd9_to_doid = pd.read_csv("ICD9_CREEDS_conversion.csv")
icd9_to_doid = pd.DataFrame(icd9_to_doid) # convert it to a data fram to drop unecessary rows
#icd9_to_doid # sanity check
icd9_to_doid_final = icd9_to_doid.drop(icd9_to_doid.columns[[0, 6, 7, 8, 9, 10, 11, 12, 13, 14]], axis = 1)  

## L1000 ANALYSIS -- FEEDS BACK INTO THE API to get additional signatures
metadata = pd.read_csv("L1000_metadata.csv")
#metadata ## same as LINC1000h5.row_metadata_df

EMR_Drug_Names = EMR_data_df['Drug_Name'] # this will be the selection for the dropdown menu
## get the subselection of drug names

# %%
###### GENERATE THE FULL ANALYSIS BETWEEN CREEDS AND L1000 GIVEN A DISEASE OF INTEREST

# USER INPUT
####
DOI = "colon adenoma" # disease of interest. CAN TAKE FROM posssible_disease_list FOR NOW
####

### DISEASE --> ICD9 --> DOI
# get the ICD9 from the DOI
DOI_ICD9 = icd9_to_doid_final[icd9_to_doid_final.Disease.apply(lambda s: bool(re.compile(DOI, re.IGNORECASE).search(s)))]
DOI_ICD9_codes = DOI_ICD9.ICD9

# get the do_id from the DOI
DOI_DOID_codes = DOI_ICD9.DOID

# get the do_id from the DOI
DOI_CREEDS_codes = DOI_ICD9.CREEDS_drug_id
    
##filter by DOI. Need to convert DOI to ICD9 first.
icd9_to_doid_final_search = icd9_to_doid_final[icd9_to_doid_final["Disease"].apply(lambda s: bool(re.compile(DOI, re.IGNORECASE).search(s)))]
icd9_to_doid_final_search1 = icd9_to_doid_final_search["ICD9"]

## rebuild the wildcard dataframe
icd9_wildcard = pd.DataFrame(icd9_to_doid_final_search1, columns=['ICD9'])
icd9_wildcard['ICD9_wildcard'] = icd9_wildcard['ICD9'].apply(lambda code: str(code).split('.')[0])
icd9_wildcard.head()

icd9_to_doid_final['ICD9_wildcard'] = icd9_to_doid_final['ICD9'].apply(lambda code: str(code).split('.')[0])
ICD9_df_joined = pd.merge(
    left=icd9_wildcard, left_on='ICD9_wildcard',
    right=icd9_to_doid_final, right_on='ICD9_wildcard',
    how='inner',
    suffixes=(
        '_Manual',
        '_right',
    )
)

emr_sub = EMR_data_df[EMR_data_df["Description"].apply(lambda s: bool(re.compile(str(DOI), re.IGNORECASE).search(str(s))))]
emr_sub.reset_index(drop = True, inplace = True)

emr_sub = []
for a in ICD9_df_joined.ICD9_wildcard.unique():
    emr_sub1 = EMR_data_df[EMR_data_df["ICD9"].apply(lambda s: bool(re.compile(str(a), re.IGNORECASE).search(str(s))))]
    emr_sub.append(emr_sub1)
emr_sub_df = pd.concat(emr_sub)
top_drugs_from_disease = list(emr_sub_df.Drug_Name[0:5]) #take the top 5 drugs
top_drugs_from_disease


single_word_drugs = []
for i in top_drugs_from_disease:
    j = str(i)
    splitted = j.split()
    first_word = splitted[0]
    single_word_drugs.append(first_word) 
single_word_drugs = list(set(single_word_drugs))


# Generate a blacklist process
def process_blacklist(s):
    import re
    blacklist = [
        # remove the classifications of the drugs
        re.compile(r'INJ', re.IGNORECASE),
        re.compile(r'CAP', re.IGNORECASE),
        re.compile(r'\d+', re.IGNORECASE),
        
        # remove drugs that aren't in the L1000
        re.compile(r'SODIUM', re.IGNORECASE),
        re.compile(r'HEPATITIS', re.IGNORECASE),
        re.compile(r'HEPARIN', re.IGNORECASE),
        re.compile(r'CALCIUM', re.IGNORECASE),
        
    ]
    for b in blacklist:
        s = re.sub(b, '', s)
    return s.strip()
single_word_drugs_list = list(pd.Series(single_word_drugs).map(process_blacklist))
single_word_drugs_list


## L1000 API Integration
L1000FWD_URL = 'http://amp.pharm.mssm.edu/L1000FWD/'


L1000_reverse_drugs_store = []
L1000_reverse_pertids_store = []

drug_and_perts = pd.DataFrame()
for a in single_word_drugs_list:
    query_string = a
    L1000_reverse_drug_response = requests.get(L1000FWD_URL + 'synonyms/' + query_string)
    if L1000_reverse_drug_response.status_code == 200:
        #pprint(L1000_reverse_drug_response.json())
        L1000_reverse_significant_query = L1000_reverse_drug_response.json()
        if len(L1000_reverse_significant_query) > 0:
            #json.dump(L1000_reverse_drug_response.json(), open(query_string + '_L1000_reverse_drug_query.json', 'w'), indent=4)
            L1000_reverse_significant_query = L1000_reverse_drug_response.json()
            L1000_reverse_significant_query_df = pd.DataFrame(L1000_reverse_significant_query)
            L1000_reverse_pertids_store.append(list(L1000_reverse_significant_query_df["pert_id"]))
            
            # store the drug name with the pert ID
            drug_and_perts = drug_and_perts.append(L1000_reverse_significant_query_df)
            
            L1000_reverse_drugs_store.append(a)            
            print("Found significant L1000 drug signatures for " + query_string)            
        else:
            print("No significant L1000 drug signatures for " + query_string)     
  
    
L1000_reverse_pertids_flat = []
for sublist in L1000_reverse_pertids_store:
    for item in sublist:
        L1000_reverse_pertids_flat.append(item) 

L1000_reverse_pertids_flat = set(list(L1000_reverse_pertids_flat)) & set(list(metadata["pert_id"])) & set(list(L1000_up_lookup.keys()))

DrOI_disease_up_signatures = {k: L1000_up_lookup[k] for k in (L1000_reverse_pertids_flat)}
DrOI_disease_up_no_perts = {k: v for d in DrOI_disease_up_signatures.values() for k, v in d.items()}
DrOI_disease_up_drug_sigs = list(DrOI_disease_up_no_perts.keys())

DrOI_disease_down_signatures = {k: L1000_down_lookup[k] for k in (L1000_reverse_pertids_flat)}
DrOI_disease_down_no_perts = {k: v for d in DrOI_disease_down_signatures.values() for k, v in d.items()}
DrOI_disease_down_drug_sigs = list(DrOI_disease_down_no_perts.keys())

DrOI_disease_all_sigs = set(DrOI_disease_up_drug_sigs) & set(DrOI_disease_down_drug_sigs)

for a in DrOI_disease_all_sigs:
    L1000_up_json_file = DrOI_disease_up_no_perts[a]
    L1000_down_json_file = DrOI_disease_down_no_perts[a]
    #with open(a + "_L1000_disease_up_sig.json", "w") as f:
        #json.dump(L1000_up_json_file, f)
   # with open(a + "_L1000_disease_down_sig.json", "w") as f:
        #json.dump(L1000_down_json_file, f)
# Out:
# Found significant L1000 drug signatures for Midazolam
# No significant L1000 drug signatures for Fentanyl
# Found significant L1000 drug signatures for Propofol

# %%
drug_and_perts = pd.DataFrame()
for a in single_word_drugs_list:
    query_string = a
    L1000_reverse_drug_response = requests.get(L1000FWD_URL + 'synonyms/' + query_string)
    if L1000_reverse_drug_response.status_code == 200:
        #pprint(L1000_reverse_drug_response.json())
        L1000_reverse_significant_query = L1000_reverse_drug_response.json()
        if len(L1000_reverse_significant_query) > 0:
            #json.dump(L1000_reverse_drug_response.json(), open(query_string + '_L1000_reverse_drug_query.json', 'w'), indent=4)
            L1000_reverse_significant_query = L1000_reverse_drug_response.json()
            L1000_reverse_significant_query_df = pd.DataFrame(L1000_reverse_significant_query)
            L1000_reverse_pertids_store.append(list(L1000_reverse_significant_query_df["pert_id"]))
            
            drug_and_perts = drug_and_perts.append(L1000_reverse_significant_query_df)
            
            L1000_reverse_drugs_store.append(a)            
            print("Found significant L1000 drug signatures for " + query_string)            
        else:
            print("No significant L1000 drug signatures for " + query_string)     
            
            
    
L1000_reverse_pertids_flat = []
for sublist in L1000_reverse_pertids_store:
    for item in sublist:
        L1000_reverse_pertids_flat.append(item) 


L1000_reverse_pertids_flat = set(list(L1000_reverse_pertids_flat)) & set(list(metadata["pert_id"])) & set(list(L1000_up_lookup.keys()))
drug_and_perts_final = pd.DataFrame()
for q in (L1000_reverse_pertids_flat):
    drug_and_perts_final = drug_and_perts_final.append(drug_and_perts[drug_and_perts["pert_id"] == q])
    

DrOI_disease_up_signatures = {k: L1000_up_lookup[k] for k in (L1000_reverse_pertids_flat)}
DrOI_disease_up_no_perts = {k: v for d in DrOI_up_signatures.values() for k, v in d.items()}
DrOI_disease_up_drug_sigs = list(DrOI_disease_up_no_perts.keys())
# Out:
# Found significant L1000 drug signatures for Midazolam
# No significant L1000 drug signatures for Fentanyl
# Found significant L1000 drug signatures for Propofol

# %%
list(drug_and_perts_final[drug_and_perts_final["pert_id"] == list(DrOI_disease_up_signatures.keys())].Name)
# Out:
# ['PROPOFOL']

# %%
drug_and_perts_final
# Out:
#        Name        pert_id
# 0  PROPOFOL  BRD-K82255054

# %%
DrOI_disease_up_no_perts
# Out:
# {'CPC014_HT29_6H:BRD-K71879491-001-22-6:10': ['TAP1',
#   'FXYD2',
#   'TSPAN12',
#   'CPD',
#   'HBB',
#   'PODXL',
#   'SCO2',
#   'APOC1',
#   'FBLN1',
#   'S100A12',
#   'SLC30A1',
#   'DDX39A',
#   'STUB1',
#   'BHLHE41',
#   'GPR183',
#   'CIAPIN1',
#   'DHRS3',
#   'LYZ',
#   'PCF11',
#   'MARCKS',
#   'C13ORF15',
#   'ARHGEF10',
#   'CDKN2C',
#   'SOD2',
#   'PLBD1',
#   'TSC22D1',
#   'ABP1',
#   'TSC22D3',
#   'IFI30',
#   'FCGBP',
#   'TSPAN1',
#   'SSH3',
#   'FZD10',
#   'TMEM176B',
#   'LY96',
#   'PATZ1',
#   'CTSS',
#   'GATA2',
#   'KRAS',
#   'VAT1',
#   'CX3CR1',
#   'KIAA0930',
#   'CCND1',
#   'ACSL1',
#   'RBBP6',
#   'C1QA',
#   'PTEN',
#   'CEP70',
#   'TYROBP',
#   'LXN',
#   'CTBP2',
#   'APOBEC3G',
#   'FBP1',
#   'IL7R',
#   'CCL5',
#   'HP',
#   'GPM6B',
#   'COPS6',
#   'FCN1',
#   'CCDC86',
#   'PDZK1IP1',
#   'EDNRA',
#   'EDNRB',
#   'FAM13A',
#   'PHLDA1',
#   'IGKC',
#   'NKG7',
#   'OLFM4',
#   'PARP8',
#   'TCTN1',
#   'GUCY1A3',
#   'PPP6C',
#   'MSMB',
#   'TACSTD2',
#   'SULT1C2',
#   'G0S2',
#   'VNN1',
#   'C10ORF116',
#   'CDK6',
#   'SLC14A1',
#   'FOS',
#   'GBP1',
#   'PSMB8',
#   'TP53I3',
#   'SAMM50',
#   'SLC39A8',
#   'PPARG',
#   'C8ORF4',
#   'ZNF586',
#   'HCK',
#   'AKR7A2',
#   'ZEB2',
#   'FSD1',
#   'IRF1',
#   'GZMB',
#   'MED13L',
#   'TNFAIP6',
#   'TCN1',
#   'CD93',
#   'TNFAIP3',
#   'TNFAIP2',
#   'GPX1',
#   'PTGER4',
#   'CD14',
#   'ITGAM',
#   'CCDC88A',
#   'PPP2R5E',
#   'TTC39A',
#   'CXCL10',
#   'LOC100505650',
#   'IGKV4-1',
#   'BAG1',
#   'BTN3A2',
#   'BHMT',
#   'MYO1F',
#   'FOSB',
#   'CYP4B1',
#   'SLC4A4',
#   'MCF2L',
#   'PTGER2',
#   'RHOB',
#   'HSPB8',
#   'C9ORF95',
#   'TBC1D8',
#   'FCER1G',
#   'EVI2B',
#   'SIK1',
#   'TRBC1',
#   'DNAJB1',
#   'IGHM',
#   'CAST',
#   'S100A9',
#   'S100A8',
#   'GALNT3',
#   'CST7',
#   'SCUBE2',
#   'CLIC4',
#   'RRS1',
#   'BIRC3',
#   'NAT1',
#   'SLC22A4',
#   'S100P',
#   'FERMT1',
#   'VCAM1',
#   'ADA',
#   'CD8A',
#   'FAIM',
#   'CP',
#   'ADAM28',
#   'GZMA',
#   'EPB41L3',
#   'GALNT14',
#   'MICALL1',
#   'LRRC32',
#   'RARRES2',
#   'RARRES3',
#   'RARRES1',
#   'FAM107A',
#   'BASP1',
#   'FIS1',
#   'PSMB9',
#   'ABCA1',
#   'MME',
#   'MMD',
#   'PSCA',
#   'CA1',
#   'MCL1',
#   'DTX4',
#   'IDO1',
#   'PCOLCE2',
#   'LCN2',
#   'PSMD4',
#   'VCAN',
#   'TFF1',
#   'PSMD2',
#   'MRPS16',
#   'CLGN',
#   'ALOX5AP',
#   'EVI2A',
#   'MAP7',
#   'PAEP',
#   'CXCL9',
#   'ELF3',
#   'GZMK',
#   'P2RX5',
#   'ARID4B',
#   'SOX4',
#   'C1QB',
#   'FYB',
#   'DDX17',
#   'MYO15B',
#   'GCLC',
#   'ETS1',
#   'CRISP3',
#   'FPR1',
#   'CYB5A',
#   'GNLY',
#   'SPINK1',
#   'EDF1',
#   'SPON1',
#   'ITGB2',
#   'FCGR1B',
#   'CA12',
#   'CLU',
#   'MS4A6A',
#   'AHNAK2',
#   'DACH1',
#   'UCP2',
#   'CD24',
#   'SLA',
#   'COPS7A',
#   'SQSTM1',
#   'TAX1BP3',
#   'CASP1',
#   'KLRK1',
#   'CFD',
#   'CFB',
#   'NRIP1',
#   'TYMP',
#   'FES',
#   'MMP7',
#   'MLPH'],
#  'CPC014_PC3_24H:BRD-K71879491-001-22-6:10': ['PCK2',
#   'MYH10',
#   'NEBL',
#   'CPM',
#   'SFTPB',
#   'CRLF1',
#   'FBXO11',
#   'EPB41L4B',
#   'SFTPA2',
#   'SCO2',
#   'UQCRH',
#   'GPM6B',
#   'SLC25A15',
#   'POLR3K',
#   'SPINT2',
#   'RGS4',
#   'PRG2',
#   'RBM34',
#   'SELENBP1',
#   'DDX39A',
#   'FKBP11',
#   'PTPLB',
#   'NAV2',
#   'ZC3H15',
#   'MYC',
#   'FGG',
#   'HMG20B',
#   'RNASE1',
#   'WT1',
#   'TSPAN13',
#   'DDX3Y',
#   'NARS2',
#   'ASNSD1',
#   'VIPR1',
#   'BZRAP1',
#   'PASK',
#   'SERPINB9',
#   'RBP1',
#   'LPL',
#   'MST4',
#   'KLK5',
#   'PHGDH',
#   'MT1E',
#   'MT1M',
#   'USP36',
#   'BMP2',
#   'ID4',
#   'ACSL5',
#   'ENC1',
#   'TSPAN3',
#   'BST2',
#   'CSRP1',
#   'STC2',
#   'LEPROTL1',
#   'PAK1',
#   'SCN3B',
#   'FBP1',
#   'IL7R',
#   'FCN3',
#   'ATP9A',
#   'SLC7A8',
#   'C7ORF23',
#   'ALB',
#   'ERG',
#   'NUP85',
#   'SLC7A1',
#   'MFSD10',
#   'WIF1',
#   'POLR1D',
#   'NPTX2',
#   'NOP16',
#   'FAM189A2',
#   'EXOSC4',
#   'CD48',
#   'XIST',
#   'DTL',
#   'MT1X',
#   'HSPH1',
#   'PER2',
#   'PLEKHJ1',
#   'C4BPA',
#   'APOH',
#   'PPM1H',
#   'EPPK1',
#   'AHSA1',
#   'GUCY1A3',
#   'MT1H',
#   'PSMG1',
#   'NANOG',
#   'TNS3',
#   'CCL20',
#   'MT1F',
#   'MT1G',
#   'PRSS21',
#   'GCA',
#   'TMPRSS3',
#   'CLNS1A',
#   'EFS',
#   'LMCD1',
#   'SLC39A8',
#   'RPS4Y1',
#   'BOP1',
#   'ZNF586',
#   'BTG3',
#   'SCGB1A1',
#   'SLC39A4',
#   'POLR2H',
#   'ZBTB16',
#   'FAM57A',
#   'DEPTOR',
#   'MTHFD2',
#   'LRIG1',
#   'ESR1',
#   'IVL',
#   'SST',
#   'GCH1',
#   'NLRP2',
#   'TEK',
#   'DDAH1',
#   'LY75',
#   'GPR126',
#   'POLE2',
#   'GPX7',
#   'MPZL2',
#   'GABRE',
#   'SFTPD',
#   'GPNMB',
#   'EIF4A1',
#   'ASPN',
#   'SSB',
#   'STX1A',
#   'VSNL1',
#   'PNN',
#   'AMPD2',
#   'CLDN18',
#   'SMAD7',
#   'CYP4B1',
#   'C20ORF103',
#   'SFTPC',
#   'XYLT1',
#   'GLS',
#   'GPRC5A',
#   'HPGD',
#   'MDN1',
#   'SLC19A3',
#   'AREG',
#   'FASTKD5',
#   'JMJD6',
#   'FZD5',
#   'MPZL1',
#   'DNAJB1',
#   'CYFIP2',
#   'RPL10',
#   'SS18L2',
#   'C1QBP',
#   'ACAT1',
#   'PDZD2',
#   'ICAM3',
#   'S100A4',
#   'TES',
#   'SLCO4A1',
#   'CADM1',
#   'P4HTM',
#   'LY6E',
#   'UBE2N',
#   'RRS1',
#   'QDPR',
#   'DDX21',
#   'CRHBP',
#   'ANO1',
#   'LDLR',
#   'MAST4',
#   'PLAC8',
#   'CLU',
#   'TRPS1',
#   'PPP1R16B',
#   'FHOD1',
#   'SFRP1',
#   'RAB33A',
#   'ATP6V1H',
#   'MICALL1',
#   'NTS',
#   'GSTM3',
#   'LRRN3',
#   'ID1',
#   'BCOR',
#   'SLC5A3',
#   'EMP2',
#   'EREG',
#   'HSPE1',
#   'PSMB8',
#   'MMD',
#   'AMIGO2',
#   'SYBU',
#   'CCDC85B',
#   'NBEAL2',
#   'AHSG',
#   'PPP2R1B',
#   'MT2A',
#   'OPN3',
#   'UFM1',
#   'CD58',
#   'TOB1',
#   'USP7',
#   'CORO1A',
#   'MRPS12',
#   'SLC5A6',
#   'CACYBP',
#   'SORBS2',
#   'P2RX5',
#   'SERPINA1',
#   'KLF10',
#   'PRPS2',
#   'CHORDC1',
#   'CBS',
#   'PUS7',
#   'KLF7',
#   'ST5',
#   'RFTN1',
#   'RPIA',
#   'APOA2',
#   'TTR',
#   'LPCAT1',
#   'AMD1',
#   'DNMT3B',
#   'PLS3',
#   'APOB',
#   'TPST2',
#   'LTBP2',
#   'CD44',
#   'NINJ2',
#   'LSM7',
#   'MT1P2',
#   'MRS2',
#   'MCM4',
#   'EPCAM',
#   'LEFTY1',
#   'PBX1',
#   'DPH2',
#   'CFI',
#   'ECHDC3',
#   'HNRNPA3',
#   'PDE2A',
#   'DGAT1',
#   'REC8',
#   'ANK3',
#   'DKC1',
#   'SLC1A4',
#   'RBP4',
#   'FOLR1'],
#  'ASG001_MCF7_24H:BRD-K71879491-001-17-6:2': ['CD38',
#   'HSPA2',
#   'NETO2',
#   'LRPPRC',
#   'MLEC',
#   'EPB41L4B',
#   'NQO1',
#   'RAPGEF5',
#   'PCK1',
#   'CAPRIN1',
#   'SLC25A13',
#   'EGF',
#   'GPR37',
#   'COL11A1',
#   'CTSS',
#   'EIF5',
#   'BHLHE41',
#   'ACSM3',
#   'DHRS3',
#   'OLFML3',
#   'CXCL14',
#   'PYGB',
#   'SPTLC2',
#   'SLC12A2',
#   'GOT2',
#   'FAM129A',
#   'FAM171A1',
#   'METTL7A',
#   'ERBB3',
#   'ARHGEF12',
#   'SLC38A1',
#   'DNAJC10',
#   'IMP4',
#   'CLMN',
#   'TSC22D3',
#   'ENPP2',
#   'ATP1B1',
#   'SERPINB9',
#   'RBP1',
#   'BAMBI',
#   'TNIP1',
#   'TBL2',
#   'CHERP',
#   'KLK6',
#   'TMEM176B',
#   'CXCL11',
#   'TSPAN8',
#   'IL6ST',
#   'PDE8A',
#   'NOX1',
#   'CXCL1',
#   'SNAP25',
#   'CXCL3',
#   'PTMA',
#   'POU2AF1',
#   'HSD11B2',
#   'SCARB1',
#   'FA2H',
#   'TRA2A',
#   'LDHB',
#   'PRSS23',
#   'S100P',
#   'PAK6',
#   'CHAC1',
#   'ACTA2',
#   'GCA',
#   'VDR',
#   'DMD',
#   'MMP12',
#   'ATP2A3',
#   'SKAP2',
#   'NFKBIA',
#   'ITGA6',
#   'HOXC6',
#   'FABP1',
#   'PDZK1IP1',
#   'BAZ2B',
#   'FAM13A',
#   'KLHDC2',
#   'DPEP1',
#   'PEG10',
#   'GDF15',
#   'CLC',
#   'MMP3',
#   'TMEM123',
#   'CCNE2',
#   'EGR1',
#   'GATM',
#   'TKT',
#   'CEACAM5',
#   'CEACAM6',
#   'TNS3',
#   'FNDC3B',
#   'SAMD9',
#   'DLX2',
#   'EPHB2',
#   'KRT20',
#   'IL5RA',
#   'NLGN4X',
#   'HERC5',
#   'GFOD1',
#   'CDC25B',
#   'CUX1',
#   'HOXB6',
#   'HOXB7',
#   'SLC39A8',
#   'IGFBP3',
#   'IGFBP6',
#   'DDC',
#   'ZBTB16',
#   'PLBD1',
#   'PLAGL1',
#   'PLSCR1',
#   'SDC1',
#   'SDC4',
#   'RBPMS',
#   'LY75',
#   'YAP1',
#   'GPX2',
#   'ELOVL2',
#   'STK39',
#   'WNT5A',
#   'KDM3A',
#   'ITGAE',
#   'EFNB2',
#   'LGR5',
#   'RAD23B',
#   'VSNL1',
#   'WBSCR22',
#   'PSMB10',
#   'UGT8',
#   'DEFB1',
#   'RFC3',
#   'GNG11',
#   'MAPK13',
#   'HPSE',
#   'IDE',
#   'DACT1',
#   'UCP2',
#   'AKR1C3',
#   'SORL1',
#   'TICAM1',
#   'FCER1A',
#   'BTG2',
#   'BTG1',
#   'MECOM',
#   'CSF2RB',
#   'NR2F6',
#   'CDKN1C',
#   'PPBP',
#   'PTGER3',
#   'CNPY3',
#   'RAB15',
#   'TNFSF4',
#   'MARCKSL1',
#   'SRC',
#   'EPB41L3',
#   'EPB41L2',
#   'CKS2',
#   'IL7R',
#   'SRI',
#   'JUND',
#   'NUP214',
#   'FERMT1',
#   'ALDH3A1',
#   'CST3',
#   'UCHL1',
#   'RMND5A',
#   'LGALS4',
#   'ST6GALNAC5',
#   'MME',
#   'SEMA3C',
#   'F3',
#   'GALNT12',
#   'KIF1A',
#   'C20ORF24',
#   'PIP5K1B',
#   'ALOX5',
#   'MTF2',
#   'HOXA5',
#   'HOXA4',
#   'ISG20',
#   'GPA33',
#   'IL8',
#   'GNAS',
#   'DNPEP',
#   'AUTS2',
#   'TBXA2R',
#   'LEFTY1',
#   'CAB39',
#   'BIRC2',
#   'FOXO3',
#   'FOXO1',
#   'LAMA3',
#   'RUNX1T1',
#   'MCL1',
#   'LEPREL1',
#   'PRSS8',
#   'SORBS3',
#   'ITGB1BP1',
#   'ELF3',
#   'S100B',
#   'HBB',
#   'KYNU',
#   'SERPINA5',
#   'NEFL',
#   'KCNK1',
#   'ETS2',
#   'UBE2G1',
#   'SERPINI1',
#   'MBP',
#   'MDFIC',
#   'SPINK1',
#   'CCDC56',
#   'PDGFD',
#   'ATP10B',
#   'CD46',
#   'TMPRSS4',
#   'PRKCD',
#   'C8ORF4',
#   'PLAT',
#   'LGALS3BP',
#   'PTPRO',
#   'CYBA',
#   'KAT6B',
#   'TUBA4A',
#   'TSKU',
#   'CD24',
#   'SMOX',
#   'EHF',
#   'BACE2',
#   'NRIP3',
#   'PSAT1',
#   'FUT3',
#   'ATF5',
#   'TGFBI',
#   'PTCH1',
#   'ABCC3'],
#  'ASG001_PC3_6H:BRD-K71879491-001-17-6:10': ['BAG2',
#   'FKBP14',
#   'PPAP2B',
#   'CKB',
#   'LYPLA1',
#   'CHN1',
#   'TNNC2',
#   'TMEM185B',
#   'IGKC',
#   'BICC1',
#   'GLI2',
#   'PPP1R3C',
#   'DENND2D',
#   'BHLHE41',
#   'FKBP11',
#   'PTPLA',
#   'RORA',
#   'PLA2G7',
#   'ERBB2',
#   'TYRP1',
#   'SLC38A1',
#   'CXADR',
#   'IDH2',
#   'DAAM2',
#   'WNK1',
#   'CYP4B1',
#   'UTP14A',
#   'OSBPL8',
#   'KLK3',
#   'KCNN3',
#   'ACPP',
#   'GATA2',
#   'IGKV1-5',
#   'IGKV4-1',
#   'VEGFA',
#   'FN1',
#   'PTMA',
#   'POU2AF1',
#   'PTPN13',
#   'DDX42',
#   'GRB14',
#   'VIM',
#   'ELK3',
#   'NPY',
#   'SPINK1',
#   'TLR4',
#   'AMMECR1',
#   'PAK4',
#   'CHAC1',
#   'SLC19A2',
#   'MAL',
#   'ITGA8',
#   'PDXK',
#   'RRAD',
#   'MACF1',
#   'LIMCH1',
#   'GPR137B',
#   'ARHGAP6',
#   'MAFB',
#   'DPYSL3',
#   'PPP1R1A',
#   'NEBL',
#   'EGR3',
#   'TUBA1A',
#   'DCTD',
#   'CHMP6',
#   'GUCY1A3',
#   'AHNAK2',
#   'CCL20',
#   'TNS1',
#   'TMEM45A',
#   'RHOQ',
#   'EPHB2',
#   'GSPT2',
#   'TMPRSS3',
#   'C7ORF44',
#   'GFOD1',
#   'PDLIM3',
#   'MN1',
#   'CDC25A',
#   'GUCY1B3',
#   'UBE2E1',
#   'PMEPA1',
#   'PID1',
#   'RPS4Y1',
#   'COL4A3',
#   'IGFBP7',
#   'ITPR1',
#   'POLR2I',
#   'CSGALNACT1',
#   'EPAS1',
#   'AMIGO2',
#   'LGMN',
#   'CD99',
#   'SDC1',
#   'SDC2',
#   'LRRC15',
#   'ITGAV',
#   'CDC20',
#   'MEF2C',
#   'CBS',
#   'GAS1',
#   'FLNA',
#   'MSLN',
#   'SON',
#   'EFNB2',
#   'ZNF238',
#   'ACTC1',
#   'SMAD1',
#   'GPNMB',
#   'RPS5',
#   'ACTA1',
#   'ATP5O',
#   'IGLV2-23',
#   'IL1B',
#   'HPGD',
#   'MCM3AP',
#   'CAPG',
#   'CYP1B1',
#   'IGLV3-19',
#   'FAT4',
#   'DNAJB6',
#   'TPM1',
#   'CAST',
#   'SPARC',
#   'FHL1',
#   'DSG2',
#   'IGL@',
#   'S100A7',
#   'DUSP2',
#   'ACTN2',
#   'SEPHS1',
#   'MMP3',
#   'ZFP36L1',
#   'FERMT2',
#   'ENO3',
#   'MXRA7',
#   'SLC43A3',
#   'IGLJ3',
#   'SLC27A3',
#   'DEGS1',
#   'DICER1',
#   'LRRFIP1',
#   'MICALL1',
#   'IL11',
#   'PDLIM5',
#   'MB',
#   'ALDH2',
#   'PDE4DIP',
#   'LMCD1',
#   'OXCT1',
#   'EREG',
#   'NKX3-1',
#   'COL1A1',
#   'MAGEA6',
#   'SET',
#   'ZMIZ1',
#   'S100A2',
#   'GPSM2',
#   'CD52',
#   'TGFB1',
#   'DPT',
#   'ACVR1',
#   'CREG1',
#   'PRDX4',
#   'VCAN',
#   'CLGN',
#   'SLC5A3',
#   'EDNRA',
#   'MAGEA3',
#   'LOX',
#   'ODC1',
#   'SIM2',
#   'HDGFRP3',
#   'RAB31',
#   'PDE1A',
#   'IGHD',
#   'DDX18',
#   'PFKP',
#   'ETS2',
#   'ACAA2',
#   'DNAJC15',
#   'CXCR7',
#   'CRISP3',
#   'HOMER1',
#   'IVNS1ABP',
#   'DAPK1',
#   'AMD1',
#   'RRAGD',
#   'GREM1',
#   'GLIPR1',
#   'PRKCB',
#   'CTAG2',
#   'KYNU',
#   'GPC4',
#   'PPP3CA',
#   'DUSP14',
#   'IGHM',
#   'MAGEA12',
#   'PFKFB3',
#   'WNT5B',
#   'KLK2',
#   'SLC16A7',
#   'FUCA1',
#   'DSE',
#   'MMP9',
#   'ABCC4',
#   'TGFBI',
#   'FOLR1',
#   'ATF3'],
#  'ASG001_PC3_6H:BRD-K71879491-001-17-6:0.4': ['EFNB2',
#   'LIF',
#   'PCK1',
#   'PPP3R1',
#   'HSPA2',
#   'OLFM1',
#   'ADA',
#   'ABP1',
#   'PTGS1',
#   'HBB',
#   'LAPTM5',
#   'CHN1',
#   'CDC42EP3',
#   'TNNC2',
#   'MYL1',
#   'APLP1',
#   'SEMA4C',
#   'ASS1',
#   'PRPF4',
#   'GSN',
#   'FKBP10',
#   'B3GNT2',
#   'MT1M',
#   'GPR183',
#   'DHRS3',
#   'PRAF2',
#   'MAP3K5',
#   'RCAN1',
#   'GRWD1',
#   'RELN',
#   'PTP4A3',
#   'RELB',
#   'TSPAN12',
#   'LUC7L3',
#   'CDC42BPA',
#   'IFITM2',
#   'HPCAL1',
#   'RAB5C',
#   'MUC2',
#   'IDH2',
#   'SYNJ2',
#   'ENPP2',
#   'HOXD1',
#   'GUSBP11',
#   'RBP1',
#   'IMPA2',
#   'TSPAN7',
#   'KLK6',
#   'CXCL14',
#   'CXCL1',
#   'INPP5A',
#   'PCGF2',
#   'CXCL5',
#   'BMP2',
#   'PTMA',
#   'CCND1',
#   'LITAF',
#   'MYLK',
#   'PPFIBP1',
#   'CD3EAP',
#   'GUCY1B3',
#   'CSRP1',
#   'DLK1',
#   'REG3A',
#   'CSF2RB',
#   'UGCG',
#   'VDR',
#   'ISG20L2',
#   'SACS',
#   'MMP12',
#   'CDKN1C',
#   'DES',
#   'ITGA4',
#   'CDC5L',
#   'HOXC6',
#   'SPON1',
#   'SLC25A36',
#   'SLC25A32',
#   'NDRG1',
#   'EDNRB',
#   'MTDH',
#   'MAPKAPK2',
#   'EIF5A',
#   'TNNT1',
#   'UBE3B',
#   'PLAC8',
#   'JAM3',
#   'THBS1',
#   'GATM',
#   'JUP',
#   'TFRC',
#   'TTN',
#   'CCL20',
#   'TOP2A',
#   'EPHB2',
#   'KCNK3',
#   'PDLIM3',
#   'MN1',
#   'RPP25',
#   'IGFBP3',
#   'SLC26A2',
#   'SLC26A3',
#   'PRKCA',
#   'HSPB8',
#   'IGFBP4',
#   'DDC',
#   'PTGES',
#   'SLC39A4',
#   'RHOF',
#   'CD74',
#   'TUBB2B',
#   'EGLN3',
#   'RPS6KA1',
#   'OLFML2A',
#   'LMNB1',
#   'ACTA1',
#   'BCL2A1',
#   'SST',
#   'SDC2',
#   'PSMD10',
#   'CDC20',
#   'MEF2C',
#   'GPX3',
#   'C9ORF3',
#   'ANPEP',
#   'FLNC',
#   'NUTF2',
#   'MYH11',
#   'GPER',
#   'ACTC1',
#   'FOSB',
#   'MKNK1',
#   'PRKDC',
#   'DYRK3',
#   'SYNM',
#   'HNRNPH1',
#   'CTNND1',
#   'FABP1',
#   'CLCA1',
#   'NES',
#   'HLA-DRB1',
#   'SET',
#   'NUSAP1',
#   'MECOM',
#   'ZEB1',
#   'TPM2',
#   'TPM1',
#   'HBEGF',
#   'FHL1',
#   'HNRNPL',
#   'FOSL2',
#   'UGT2B17',
#   'DLC1',
#   'RAB14',
#   'FOXF1',
#   'TBXA2R',
#   'LY6D',
#   'ELN',
#   'ABCG1',
#   'BCL11A',
#   'HNRNPA0',
#   'B4GALT6',
#   'NAA15',
#   'SH2B3',
#   'FA2H',
#   'CHRNA3',
#   'LGALS1',
#   'CHP2',
#   'FAM171A1',
#   'CCL11',
#   'EMILIN1',
#   'TACC1',
#   'MB',
#   'ID3',
#   'AGPAT5',
#   'HLA-DPA1',
#   'MMD',
#   'GATAD2A',
#   'TMEM204',
#   'IL8',
#   'KCTD5',
#   'TYRP1',
#   'CHGB',
#   'CIT',
#   'MGLL',
#   'TFF3',
#   'CLEC2B',
#   'KIAA0125',
#   'SLC5A6',
#   'KIAA1033',
#   'TRPA1',
#   'HIP1',
#   'CPSF1',
#   'HLA-DRA',
#   'RAB31',
#   'P2RX5',
#   'CHI3L1',
#   'LRRC8B',
#   'OPHN1',
#   'MAB21L2',
#   'IL1R2',
#   'ETS2',
#   'RGS5',
#   'CXCR7',
#   'RGS1',
#   'RGS3',
#   'CEBPZ',
#   'PACSIN3',
#   'XIST',
#   'ITGB3',
#   'ITGB2',
#   'HEATR1',
#   'NR4A2',
#   'ATP10B',
#   'RTN2',
#   'PLAT',
#   'SLN',
#   'TMEM164',
#   'BACE1',
#   'DPH2',
#   'CASP2',
#   'CA2',
#   'SLC16A3',
#   'CYC1',
#   'RPA3',
#   'TYMS',
#   'PRUNE2',
#   'CANT1',
#   'SUPV3L1',
#   'BCL2',
#   'BCL3',
#   'FUT8'],
#  'HOG002_MCF7_24H:BRD-K71879491-001-22-6:3.3333': ['HIST1H4C',
#   'CALCA',
#   'STAT4',
#   'SCG5',
#   'POLG2',
#   'PSPC1',
#   'IL6ST',
#   'NOC3L',
#   'PLIN2',
#   'KIF2C',
#   'LMCD1',
#   'LOC100272216',
#   'GADD45A',
#   'CIAPIN1',
#   'DHRS3',
#   'FGFR3',
#   'PCF11',
#   'GRWD1',
#   'KLF4',
#   'CLINT1',
#   'PIP',
#   'LYN',
#   'SOD2',
#   'AQP3',
#   'ERBB4',
#   'CYP1A1',
#   'CYP2B7P1',
#   'PRMT1',
#   'FN1',
#   'TRIM22',
#   'UTP14A',
#   'FLRT3',
#   'FLRT2',
#   'NOP2',
#   'SNAI2',
#   'CXCL12',
#   'GATA3',
#   'BRD2',
#   'CTSW',
#   'CX3CR1',
#   'HNRPDL',
#   'TBX3',
#   'PTPN13',
#   'LIMA1',
#   'FAM46A',
#   'DDX47',
#   'ACSL5',
#   'GOLGA8H',
#   'MAF',
#   'GOLGA8A',
#   'XPNPEP1',
#   'BATF',
#   'CTPS',
#   'RPL37A',
#   'RPS27L',
#   'CCL5',
#   'PNISR',
#   'CDKN1A',
#   'PTPLAD1',
#   'DCLK1',
#   'COPS5',
#   'TNPO1',
#   'TNFRSF12A',
#   'EXOSC4',
#   'AEN',
#   'XIST',
#   'SRSF7',
#   'WDR43',
#   'NEBL',
#   'CCT2',
#   'LIMCH1',
#   'IPO7',
#   'C3',
#   'TRIAP1',
#   'PCLO',
#   'CEACAM6',
#   'RUFY3',
#   'TXNRD1',
#   'PTGES',
#   'PSG9',
#   'IGL@',
#   'DSP',
#   'RSL1D1',
#   'IGFBP6',
#   'IGFBP4',
#   'THBD',
#   'GCLM',
#   'SCUBE2',
#   'GZMB',
#   'TNFAIP6',
#   'HMOX1',
#   'DNAJC2',
#   'PSMD12',
#   'GPX2',
#   'KRT13',
#   'ASCC3',
#   'HLF',
#   'WNT5A',
#   'STX1A',
#   'EHD1',
#   'ERAP2',
#   'DHRS2',
#   'SMAD3',
#   'STOM',
#   'FABP4',
#   'KRT7',
#   'CTNND1',
#   'UPF2',
#   'GPRC5A',
#   'AKR1C1',
#   'AKR1C2',
#   'AKR1C3',
#   'DUOX2',
#   'AKR1B10',
#   'SIK1',
#   'NOTCH2NL',
#   'CGA',
#   'TPM1',
#   'SUV420H1',
#   'AKAP8L',
#   'FOSL1',
#   'DDB2',
#   'FTH1',
#   'CST7',
#   'ALDH3A1',
#   'UGDH',
#   'EIF5',
#   'FGF13',
#   'MAST2',
#   'LGALS8',
#   'SERPINF1',
#   'ARFGEF1',
#   'LGALS3',
#   'ADM',
#   'RAD51C',
#   'SRRM2',
#   'RIOK3',
#   'NUP50',
#   'RARRES3',
#   'TRAM1',
#   'MET',
#   'PSMB8',
#   'MIR22HG',
#   'PEG3',
#   'PA2G4',
#   'AMOTL2',
#   'AUTS2',
#   'KTN1',
#   'TCN1',
#   'S100P',
#   'SLCO1B3',
#   'SMARCA1',
#   'TXNL4B',
#   'KIAA0485',
#   'EIF2S1',
#   'ALDH1A1',
#   'PAPSS2',
#   'FAS',
#   'CBR3',
#   'ETS2',
#   'RRS1',
#   'IGJ',
#   'MED13',
#   'DNAJC12',
#   'RGS2',
#   'CCT6A',
#   'GNLY',
#   'HSD11B1',
#   'DHRS7B',
#   'PRKCH',
#   'PDGFC',
#   'CD44',
#   'NOLC1',
#   'KPNB1',
#   'KYNU',
#   'MTSS1',
#   'IL32',
#   'RHOBTB3',
#   'STK39',
#   'PER2',
#   'RPL35',
#   'CFB',
#   'NRIP1',
#   'EZR',
#   'SLC16A6',
#   'CHD9',
#   'MMP7',
#   'COL6A3',
#   'HLA-DQA1',
#   'CYP26A1'],
#  'NMH002_NEU_24H:BRD-K71879491-001-30-9:10': ['HIST1H4C',
#   'SSPN',
#   'USP13',
#   'SPG20',
#   'TSPAN4',
#   'CKB',
#   'MLEC',
#   'C3ORF14',
#   'NQO1',
#   'KCNMA1',
#   'ANKRD11',
#   'CLU',
#   'S100A13',
#   'SQLE',
#   'KIF2C',
#   'PPAP2B',
#   'PGCP',
#   'ACAA2',
#   'SELENBP1',
#   'ZNF148',
#   'CRLF1',
#   'EIF1AY',
#   'ZC3H15',
#   'LIG1',
#   'NID1',
#   'WWP1',
#   'PIR',
#   'METTL7A',
#   'SLC6A8',
#   'DDX3Y',
#   'LIPG',
#   'MDFIC',
#   'TRIM22',
#   'KIAA1462',
#   'BAZ1A',
#   'RBP1',
#   'FLRT2',
#   'HLA-DQA1',
#   'TPR',
#   'IFRD2',
#   'BRD2',
#   'IL6ST',
#   'MAN1A1',
#   'TDP2',
#   'NME4',
#   'BMP4',
#   'PTMA',
#   'STOM',
#   'ROBO1',
#   'IGLL3P',
#   'ANKRD36B',
#   'H2AFZ',
#   'KAL1',
#   'DTX4',
#   'CYLD',
#   'PRSS21',
#   'MAF',
#   'LXN',
#   'PLAGL1',
#   'TMEM106B',
#   'CTPS',
#   'SNX7',
#   'ELAVL1',
#   'DIRAS3',
#   'DTL',
#   'RARRES2',
#   'ALDH3A1',
#   'DCLK1',
#   'NUP85',
#   'ANXA2',
#   'GUCY1A3',
#   'LAMB1',
#   'PTGDS',
#   'NUCKS1',
#   'PHLDA1',
#   'SERPINE2',
#   'LY86',
#   'OLFM4',
#   'PTN',
#   'SRSF7',
#   'NEBL',
#   'TBX3',
#   'SCD',
#   'MDK',
#   'ZBTB38',
#   'TKT',
#   'PPAT',
#   'CCL20',
#   'IGHM',
#   'CAV1',
#   'RHOQ',
#   'TOP2A',
#   'MAPK1IP1L',
#   'C10ORF116',
#   'KIAA0485',
#   'TTC3',
#   'METRN',
#   'EFEMP1',
#   'RNF43',
#   'GBP1',
#   'EFEMP2',
#   'IGL@',
#   'NELL2',
#   'TP53I3',
#   'COL21A1',
#   'PAX6',
#   'COL4A3',
#   'MAN2A1',
#   'IGFBP5',
#   'POLR2L',
#   'PWP1',
#   'POLR2I',
#   'FGF2',
#   'PDGFC',
#   'GINS2',
#   'PLSCR4',
#   'NAA15',
#   'MTHFD1',
#   'GNAS',
#   'SDC2',
#   'UBE2C',
#   'G6PD',
#   'NYNRIN',
#   'RBPMS',
#   'TOP1',
#   'CDC20',
#   'MEIS2',
#   'ITM2A',
#   'MGP',
#   'KRT13',
#   'IGF1',
#   'BHLHE41',
#   'SULT1A1',
#   'FLNA',
#   'MSLN',
#   'NVL',
#   'CCNG1',
#   'KRT18',
#   'EPHX1',
#   'RNASE4',
#   'YY1',
#   'IQGAP1',
#   'CYP4B1',
#   'SH3BP5',
#   'DYRK3',
#   'MBD4',
#   'MBOAT7',
#   'PRPF40A',
#   'RHOB',
#   'DMD',
#   'KIAA0101',
#   'KRT8',
#   'OPN3',
#   'AKR1C1',
#   'AKR1C2',
#   'HMGB2',
#   'NCOA3',
#   'TNPO1',
#   'ATP1A2',
#   'FZD7',
#   'NR2F1',
#   'TPM1',
#   'NR2F2',
#   'AKAP8L',
#   'FHL1',
#   'PPP1R12A',
#   'PRDX6',
#   'FANCL',
#   'C7',
#   'HMGB1',
#   'GREM1',
#   'NBN',
#   'MARCKSL1',
#   'DUOX2',
#   'ELN',
#   'MTMR11',
#   'PHACTR2',
#   'ACSS3',
#   'TFPI',
#   'PITX1',
#   'ZFP36L1',
#   'SYNC',
#   'COL5A2',
#   'RNF128',
#   'MXRA5',
#   'CYCS',
#   'FAIM',
#   'PCOLCE2',
#   'DUT',
#   'YAP1',
#   'SP140L',
#   'LRP3',
#   'SEMA3C',
#   'DFNA5',
#   'HIRA',
#   'IL33',
#   'ACOX2',
#   'CADPS2',
#   'ID4',
#   'LMO3',
#   'PHGDH',
#   'ID1',
#   'HN1',
#   'SOX9',
#   'NMB',
#   'MCM4',
#   'LRRC17',
#   'IGLL1',
#   'PPIF',
#   'COCH',
#   'CFD',
#   'SEPP1',
#   'ETFA',
#   'SPHK1',
#   'PCP4',
#   'IPO13',
#   'USP1',
#   'BIRC5',
#   'PRDX4',
#   'EIF5',
#   'BAX',
#   'SLC16A4',
#   'CORO1A',
#   'EDNRA',
#   'SORBS1',
#   'COL4A3BP',
#   'MYBL2',
#   'KIAA0182',
#   'ODC1',
#   'ZNF12',
#   'GPI',
#   'SEL1L3',
#   'HDGFRP3',
#   'CCNA2',
#   'TYMS',
#   'UBQLN2',
#   'BID',
#   'CLIC1',
#   'IGHD',
#   'RHBDF2',
#   'SULF1',
#   'ALDH1A1',
#   'GLI2',
#   'HSPD1',
#   'GPX2',
#   'CXCR7',
#   'DACT1',
#   'PHLDA2',
#   'CNOT4',
#   'MATN2',
#   'HEATR2',
#   'GPX7',
#   'LTBP1',
#   'SCAF11',
#   'SRP72',
#   'KPNB1',
#   'HSPB8',
#   'C6ORF62',
#   'LGALS3BP',
#   'MCM6',
#   'QPRT',
#   'PAPSS2',
#   'MCM3',
#   'MCM2',
#   'NBPF10',
#   'SCML1',
#   'CALD1',
#   'GTPBP8',
#   'PBX1',
#   'CA9',
#   'RAB23',
#   'TBL1X',
#   'CFI',
#   'RHOBTB3',
#   'SLC16A2',
#   'COL14A1',
#   'NRIP1',
#   'SLC2A4RG',
#   'PLOD2',
#   'PITPNC1',
#   'SUPV3L1',
#   'CAMK2N1',
#   'SLC9A3R1',
#   'TGIF1'],
#  'NMH002_NPC_24H:BRD-K71879491-001-30-9:10': ['TAP2',
#   'TIMP3',
#   'TRIM14',
#   'TIMP1',
#   'FLT1',
#   'SCG5',
#   'PRKAG2',
#   'SCG2',
#   'CD36',
#   'NEFH',
#   'PODXL',
#   'FKBP5',
#   'MFAP5',
#   'MFAP4',
#   'MS4A4A',
#   'HLA-DQA1',
#   'NKX2-2',
#   'S100A10',
#   'FBLN1',
#   'KCNK3',
#   'CAV2',
#   'KCNJ2',
#   'CAV1',
#   'DCN',
#   'CCR2',
#   'PPAP2A',
#   'C1ORF115',
#   'CALM1',
#   'TPD52',
#   'NRN1',
#   'PRNP',
#   'FAM46A',
#   'NTRK2',
#   'OAS1',
#   'INHBA',
#   'CNPY3',
#   'FOXF1',
#   'PIP',
#   'ARHGAP29',
#   'CDH5',
#   'LIPA',
#   'CRISPLD2',
#   'MAFB',
#   'NAAA',
#   'ENTPD1',
#   'NUP98',
#   'ATP1B1',
#   'ANXA11',
#   'TOMM34',
#   'KLK3',
#   'TMEM176A',
#   'TSPAN4',
#   'YIF1A',
#   'SNAI2',
#   'TSPAN8',
#   'PCSK5',
#   'GATA3',
#   'CHMP2B',
#   'FN1',
#   'CHN2',
#   'APOA1',
#   'LHFP',
#   'ARCN1',
#   'ADAMDEC1',
#   'NPY',
#   'TLR4',
#   'PRSS23',
#   'AKAP12',
#   'STC2',
#   'TSPAN31',
#   'IGSF6',
#   'ACTA2',
#   'ERAP1',
#   'TNFSF10',
#   'TNS1',
#   'CCL4',
#   'NFKBIB',
#   'OLFM4',
#   'DCLK1',
#   'RAB6A',
#   'UBE2D1',
#   'GOLT1B',
#   'SEPT8',
#   'COL3A1',
#   'RIN2',
#   'SERPINE1',
#   'PHLDA2',
#   'MME',
#   'APOD',
#   'TCF21',
#   'CDV3',
#   'CTSZ',
#   'EGR2',
#   'EGR3',
#   'LIMCH1',
#   'THBS2',
#   'PALLD',
#   'NES',
#   'TUBB6',
#   'NID1',
#   'FAM129A',
#   'MSMB',
#   'TACSTD2',
#   'GDF15',
#   'MYL9',
#   'B4GALT5',
#   'SEC13',
#   'CLDN7',
#   'PTPRN2',
#   'G0S2',
#   'C10ORF116',
#   'UBB',
#   'PDLIM2',
#   'METRN',
#   'EFEMP1',
#   'PDIA3',
#   'GBP1',
#   'MAF',
#   'A2M',
#   'CARTPT',
#   'IGFBP3',
#   'SLC26A3',
#   'IGFBP6',
#   'IGFBP7',
#   'COL4A1',
#   'IGFBP5',
#   'RFK',
#   'VWF',
#   'GIMAP6',
#   'PLAT',
#   'TMEM47',
#   'CHST7',
#   'ZEB2',
#   'CCL13',
#   'EPAS1',
#   'ABCG2',
#   'FDX1',
#   'POSTN',
#   'CD99',
#   'TNFAIP6',
#   'SDC4',
#   'SI',
#   'ITGAV',
#   'PTGER4',
#   'ITM2A',
#   'PRKCZ',
#   'IL8',
#   'FAM105A',
#   'KRT10',
#   'HES1',
#   'AGTR1',
#   'GIMAP4',
#   'ASPN',
#   'KRT18',
#   'EFNB2',
#   'ACP5',
#   'RAD23B',
#   'FILIP1L',
#   'KIAA0355',
#   'PAPOLA',
#   'RCAN2',
#   'CYP4B1',
#   'GPR124',
#   'CD4',
#   'STOM',
#   'FABP4',
#   'CD1E',
#   'KRT7',
#   'CCR5',
#   'CD2',
#   'MGP',
#   'KRT8',
#   'GPRC5A',
#   'LUM',
#   'HS3ST2',
#   'FZD1',
#   'ACTN2',
#   'MMP12',
#   'PLA2G7',
#   'TMEM30B',
#   'DNAJB1',
#   'TPM2',
#   'NR2F2',
#   'SPARC',
#   'ICAM1',
#   'DUSP5',
#   'CPVL',
#   'LOC100129361',
#   'FGL2',
#   'SPATS2L',
#   'PHACTR2',
#   'PMP22',
#   'PRDX2',
#   'COL5A2',
#   'CA1',
#   'ENO3',
#   'SERPINF1',
#   'ADA',
#   'LGALS3',
#   'ADO',
#   'TMEM176B',
#   'ADM',
#   'CPM',
#   'TMEM87A',
#   'HBB',
#   'DEGS1',
#   'F3',
#   'CCL18',
#   'PLCL1',
#   'NETO2',
#   'RARRES1',
#   'HN1',
#   'COL15A1',
#   'BASP1',
#   'COL1A2',
#   'EREG',
#   'NKX3-1',
#   'COL1A1',
#   'MAGEA6',
#   'PCDH9',
#   'NRP1',
#   'AMIGO2',
#   'ASAP1',
#   'ABCA8',
#   'SEPP1',
#   'RNASE1',
#   'AMOTL2',
#   'PCOLCE2',
#   'AQP3',
#   'CECR1',
#   'PSAP',
#   'EEF1A2',
#   'PTGIS',
#   'EIF5',
#   'CYB5A',
#   'MAP2K3',
#   'TNFAIP3',
#   'COX7A1',
#   'MAGEA3',
#   'F13A1',
#   'SORBS3',
#   'DKK1',
#   'ALDH1A1',
#   'ALDH1A3',
#   'FYB',
#   'CILP',
#   'C1QB',
#   'HDGFRP3',
#   'UBQLN2',
#   'KCNE4',
#   'NDN',
#   'MAOA',
#   'SULF1',
#   'TATDN2',
#   'LMCD1',
#   'RGS5',
#   'KLF5',
#   'ETS1',
#   'ABCB6',
#   'CHST2',
#   'JAG1',
#   'SPINK1',
#   'HSD11B1',
#   'ANXA1',
#   'SPON2',
#   'ANXA3',
#   'ANXA5',
#   'HEG1',
#   'REG1A',
#   'FXYD3',
#   'HSPB8',
#   'FBN1',
#   'SUCLG2',
#   'COL6A1',
#   'SERPINA3',
#   'C11ORF75',
#   'SPARCL1',
#   'SIDT2',
#   'TMBIM6',
#   'ALDOB',
#   'CALD1',
#   'GTPBP8',
#   'TAGLN',
#   'KCTD12',
#   'CASP7',
#   'INPP1',
#   'RNF167',
#   'NCK1',
#   'SLC35F2',
#   'SLC16A1',
#   'CA2',
#   'CFD',
#   'RAB25',
#   'NRIP1',
#   'NOTCH3',
#   'PSAT1',
#   'FUT4',
#   'FOLH1',
#   'MAPT',
#   'GNA11',
#   'PTRF',
#   'MXRA5',
#   'CAMK2N1',
#   'COL6A2',
#   'PICALM',
#   'BZW2'],
#  'HOG002_MCF7_6H:BRD-K71879491-001-22-6:0.013': ['PCK1',
#   'IFRD2',
#   'ACTG2',
#   'MYH11',
#   'FBXO11',
#   'CPE',
#   'SPRED2',
#   'TPBG',
#   'KLRB1',
#   'SRSF10',
#   'SLC25A37',
#   'ZNF419',
#   'LEPROT',
#   'FBLN1',
#   'TM7SF2',
#   'SLC39A14',
#   'EIF1AY',
#   'PTGER2',
#   'PTPLB',
#   'ZNF264',
#   'MARCKS',
#   'CALB1',
#   'ZC3HAV1',
#   'EPYC',
#   'LBH',
#   'FGG',
#   'C13ORF15',
#   'METTL7A',
#   'FGB',
#   'CDH6',
#   'RNASE1',
#   'WT1',
#   'SLC38A1',
#   'DDX3Y',
#   'COL15A1',
#   'MUC2',
#   'ENPP2',
#   'TRIM22',
#   'LEFTY1',
#   'SFRP1',
#   'EIF4A1',
#   'KLK6',
#   'TMEM176B',
#   'SNAI2',
#   'TMEM100',
#   'CXCL14',
#   'KCTD12',
#   'KLK8',
#   'CCND2',
#   'MYLK',
#   'TFPI2',
#   'ADAMDEC1',
#   'RUNX3',
#   'NPY',
#   'EID1',
#   'KDM5D',
#   'STC1',
#   'REG3A',
#   'PLXNA1',
#   'IL7R',
#   'CLEC2B',
#   'MSL1',
#   'MMP12',
#   'ZSCAN18',
#   'RARRES2',
#   'HP',
#   'NDNF',
#   'GLUL',
#   'GREM1',
#   'TOMM20',
#   'TRIB2',
#   'CLTB',
#   'CHL1',
#   'MTDH',
#   'MAFB',
#   'SERPINE2',
#   'TNNT1',
#   'PTN',
#   'IARS2',
#   'MMP3',
#   'IGFBP5',
#   'CPA3',
#   'LIMCH1',
#   'THBS1',
#   'CLDN8',
#   'AHNAK2',
#   'PIK3R1',
#   'CD44',
#   'CCL21',
#   'COLEC12',
#   'MS4A1',
#   'GDF11',
#   'ZNF281',
#   'EPHB2',
#   'IGF1',
#   'GCG',
#   'EFEMP1',
#   'CDC25B',
#   'DST',
#   'AMMECR1',
#   'TTC9',
#   'ZCCHC24',
#   'SLC39A8',
#   'KDELR2',
#   'ZBTB10',
#   'ZNF587',
#   'ZNF586',
#   'PAX5',
#   'ZNF329',
#   'AMIGO2',
#   'PSIP1',
#   'LRIG1',
#   'SDC1',
#   'TOX3',
#   'WNT5A',
#   'ACTR3',
#   'FAM5C',
#   'EPHX1',
#   'PDGFRA',
#   'NPDC1',
#   'TNFRSF11B',
#   'MKNK1',
#   'PID1',
#   'FOXF1',
#   'TBX3',
#   'LHFP',
#   'PRKAR2B',
#   'ZNF814',
#   'CLCA2',
#   'STAB1',
#   'PLN',
#   'RPS4Y1',
#   'CYP1B1',
#   'LPAR6',
#   'SGCE',
#   'SCRG1',
#   'DUSP10',
#   'CAST',
#   'IFI16',
#   'S100A9',
#   'TRMT1',
#   'C3',
#   'CITED2',
#   'C7',
#   'S100A2',
#   'NAT1',
#   'TFPI',
#   'AIM1',
#   'ZFP36L2',
#   'PLA2G2A',
#   'HOPX',
#   'SERPINF1',
#   'VCAM1',
#   'FADS1',
#   'LEF1',
#   'FSCN1',
#   'SEMA3C',
#   'F3',
#   'LRRFIP1',
#   'SGK1',
#   'CCL19',
#   'LMO2',
#   'CASP1',
#   'COL11A1',
#   'ID3',
#   'RARRES1',
#   'TRAM1',
#   'PSMB8',
#   'MMD',
#   'LPAR1',
#   'ZNF134',
#   'MPPED2',
#   'PRKD3',
#   'TGFB2',
#   'DPT',
#   'AUTS2',
#   'SPCS1',
#   'IPO13',
#   'CD59',
#   'VCAN',
#   'DKK3',
#   'MYBL1',
#   'USP9Y',
#   'PAEP',
#   'LXN',
#   'MAGEA3',
#   'LOX',
#   'PITX1',
#   'MAGEA6',
#   'ALDH1A3',
#   'WASF1',
#   'CRABP2',
#   'FAP',
#   'DEFA6',
#   'DEFA5',
#   'CRISP3',
#   'ZNF551',
#   'SPINK4',
#   'EFNA5',
#   'ADH1B',
#   'ANXA1',
#   'SPON1',
#   'MATN2',
#   'PDGFD',
#   'REG1A',
#   'REG1B',
#   'ITGB6',
#   'CDC42EP3',
#   'LSM5',
#   'ZNF304',
#   'PLAT',
#   'GPR87',
#   'RHOBTB3',
#   'TNC',
#   'C1R',
#   'SERPINA5',
#   'CALD1',
#   'NRP1',
#   'TAGLN',
#   'FERMT2',
#   'RNF167',
#   'HSPA14',
#   'C1QTNF3',
#   'CD163',
#   'NRIP1',
#   'ZNF91',
#   'SYBU',
#   'C1S',
#   'TGFBI',
#   'COL6A2',
#   'SLC1A1',
#   'ABCC3'],
#  'HOG002_A549_24H:BRD-K71879491-001-22-6:0.1234': ['DHDDS',
#   'UBE2J1',
#   'ACTG2',
#   'HSPA4',
#   'STK10',
#   'PCCA',
#   'ABP1',
#   'GRHPR',
#   'HAUS3',
#   'CHMP2B',
#   'TPBG',
#   'N4BP2L2',
#   'APOC1',
#   'ASS1',
#   'HCAR3',
#   'CPM',
#   'CLDN8',
#   'AHCYL1',
#   'DMBT1',
#   'SLC43A3',
#   'RBPJ',
#   'PILRB',
#   'PTPLB',
#   'STAP2',
#   'GRWD1',
#   'ANKRD36B',
#   'MEIS2',
#   'METTL7A',
#   'LOX',
#   'BLNK',
#   'NME4',
#   'CEACAM6',
#   'BCAT1',
#   'CGRRF1',
#   'PER3',
#   'FXR1',
#   'FAM69A',
#   'F3',
#   'MT1E',
#   'CD37',
#   'TSPAN15',
#   'SERPINB6',
#   'DBI',
#   'CCNG1',
#   'MIS12',
#   'TNIK',
#   'SFN',
#   'RUNX3',
#   'PRKAR2B',
#   'STC1',
#   'PLAGL1',
#   'PLIN2',
#   'RPS27L',
#   'RRAGD',
#   'HP',
#   'IDO1',
#   'SEC62',
#   'SLC31A1',
#   'TGM2',
#   'CLTB',
#   'PTGDS',
#   'SWAP70',
#   'SERPINE1',
#   'FNBP1L',
#   'PPP1R1A',
#   'MPHOSPH8',
#   'C4ORF19',
#   'PLEKHA5',
#   'MST4',
#   'SCD',
#   'CAP1',
#   'GRAMD3',
#   'GATM',
#   'TSPAN1',
#   'TFRC',
#   'JAK1',
#   'TGFB1I1',
#   'TMEM45A',
#   'REG3A',
#   'EPHB2',
#   'PDLIM5',
#   'G0S2',
#   'C10ORF116',
#   'CDC25B',
#   'NUPR1',
#   'ZNF22',
#   'SLC39A8',
#   'RGS13',
#   'HERC5',
#   'RAP1GDS1',
#   'PLEK',
#   'FERMT2',
#   'ABCG1',
#   'RPS6KA2',
#   'SH3BGRL3',
#   'ZDHHC6',
#   'CDC20',
#   'CBS',
#   'KCNMA1',
#   'PDZD2',
#   'FLNC',
#   'ECHDC2',
#   'TMC5',
#   'CLDN10',
#   'MKNK2',
#   'DEFB1',
#   'FAM46A',
#   'STOM',
#   'OLFM1',
#   'FABP5',
#   'HNRNPH3',
#   'PSTPIP2',
#   'CLCA1',
#   'FASTKD5',
#   'SNX11',
#   'PLA2G7',
#   'CD83',
#   'TPM4',
#   'TPM2',
#   'LXN',
#   'GPR88',
#   'CAST',
#   'OBSL1',
#   'TFPI',
#   'CITED2',
#   'RAB13',
#   'CST1',
#   'S100A2',
#   'MGLL',
#   'ZFP36L1',
#   'HMGA1',
#   'PLA2G2A',
#   'SERPINF1',
#   'SAR1A',
#   'RAD51C',
#   'ADAM28',
#   'NOL3',
#   'TAOK3',
#   'DEGS1',
#   'NMU',
#   'OLR1',
#   'CCL18',
#   'CADPS2',
#   'CD99',
#   'GLUL',
#   'RARRES1',
#   'PRKACB',
#   'SLC6A14',
#   'TBC1D16',
#   'PTK2',
#   'MT2A',
#   'LCN2',
#   'PSMD5',
#   'BIRC3',
#   'BMPR1A',
#   'GNE',
#   'C16ORF45',
#   'PIN1',
#   'KIAA0485',
#   'SMARCA2',
#   'ALDH1A3',
#   'SERPINA3',
#   'FAM149A',
#   'TWIST1',
#   'FAP',
#   'TFAP2B',
#   'TLN1',
#   'ACAA2',
#   'ALOX15B',
#   'RGS1',
#   'CRISP3',
#   'SPINK4',
#   'C14ORF132',
#   'HSD17B6',
#   'HSD11B1',
#   'DNMT3B',
#   'TNNT1',
#   'PDGFC',
#   'SLC44A4',
#   'CDC42EP3',
#   'CD44',
#   'SLC24A3',
#   'RTN2',
#   'LSM3',
#   'PAPSS2',
#   'RHOBTB3',
#   'TNC',
#   'AHNAK2',
#   'UCP2',
#   'LEFTY1',
#   'CCNB2',
#   'RAB26',
#   'SLC16A3',
#   'CFB',
#   'RPA3',
#   'SLC1A1',
#   'MYBL1',
#   'LPL',
#   'KANK2',
#   'ADH1B',
#   'NBL1',
#   'ATF5',
#   'MMP7',
#   'SERPINH1',
#   'KIAA0528',
#   'SLC1A3'],
#  'ERG005_VCAP_24H:BRD-K71879491-001-17-6:5': ['KLK12',
#   'WNT5A',
#   'PLK2',
#   'IL6ST',
#   'GATA6',
#   'FGL2',
#   'RCBTB2',
#   'NRIP3',
#   'HLA-DQA1',
#   'DAB2',
#   'BICC1',
#   'IL7R',
#   'DCN',
#   'RGS4',
#   'PPP1R3C',
#   'GUCY1B3',
#   'GATM',
#   'PTGER4',
#   'CD48',
#   'DHRS2',
#   'GUCY1A3',
#   'DYNLT3',
#   'PSD3',
#   'MARCKS',
#   'CDH1',
#   'HLA-DQB1',
#   'ARHGAP29',
#   'CDH2',
#   'CLEC7A',
#   'BLNK',
#   'CBLB',
#   'PLBD1',
#   'KRT23',
#   'CTSB',
#   'TPSB2',
#   'ATP1B1',
#   'RBP1',
#   'BAMBI',
#   'LPL',
#   'TMEM176A',
#   'EDEM1',
#   'LY96',
#   'MS4A4A',
#   'CTSS',
#   'GATA2',
#   'TUFT1',
#   'SHMT1',
#   'IGKV1-5',
#   'KCTD12',
#   'XAF1',
#   'GZMA',
#   'LST1',
#   'CX3CR1',
#   'NR1D2',
#   'GALNT6',
#   'CLEC2B',
#   'ADCY9',
#   'TCF7L2',
#   'ADAM9',
#   'SPEN',
#   'CXCL9',
#   'CSF2RB',
#   'ENC1',
#   'MTRR',
#   'CSRP1',
#   'KDELR3',
#   'STC2',
#   'CD300A',
#   'PXDN',
#   'CCR5',
#   'TNFSF13',
#   'MAD1L1',
#   'STAR',
#   'CCL4',
#   'CCL5',
#   'ALDH3A2',
#   'HLA-B',
#   'DUOX2',
#   'ITGA4',
#   'RASSF4',
#   'NKG7',
#   'HOXC6',
#   'C1QA',
#   'LYZ',
#   'COL3A1',
#   'TNS3',
#   'EIF5A',
#   'XIST',
#   'HOPX',
#   'AIF1',
#   'NNMT',
#   'CCNE2',
#   'PLAC8',
#   'LIMCH1',
#   'HEATR1',
#   'THBS1',
#   'TIAM1',
#   'DACT1',
#   'NXT1',
#   'FAM129A',
#   'ZIC1',
#   'TACSTD2',
#   'CCL20',
#   'IGHM',
#   'FAM108A1',
#   'C3',
#   'VNN1',
#   'FLRT3',
#   'NKX3-1',
#   'KIAA0196',
#   'ENG',
#   'CPA3',
#   'MAF',
#   'FCGR2C',
#   'IGFBP3',
#   'ZWILCH',
#   'PTPN1',
#   'CAPG',
#   'GALNT1',
#   'TRBC1',
#   'C10ORF10',
#   'CYBB',
#   'IRF1',
#   'GINS1',
#   'RBFOX2',
#   'HOXC10',
#   'SDC1',
#   'SDC4',
#   'RBPMS',
#   'TNFAIP3',
#   'GZMK',
#   'RYR1',
#   'ITM2A',
#   'MGP',
#   'LPXN',
#   'RNF128',
#   'HES1',
#   'TPSAB1',
#   'PEG3',
#   'ITGAE',
#   'KRT19',
#   'IGKV4-1',
#   'EPHX1',
#   'IQGAP1',
#   'FCGR2B',
#   'CD84',
#   'RBP4',
#   'EVI2A',
#   'RPL37A',
#   'POLB',
#   'CD2',
#   'SRGN',
#   'PSTPIP2',
#   'KIAA0101',
#   'GPRC5A',
#   'LUM',
#   'MLF1',
#   'NEDD9',
#   'BTG2',
#   'CGA',
#   'ALCAM',
#   'TSPAN5',
#   'PTX3',
#   'GPNMB',
#   'NRP1',
#   'IFI16',
#   'ICAM2',
#   'DDB2',
#   'DUSP4',
#   'S100A6',
#   'IGSF6',
#   'C5',
#   'PLXNC1',
#   'NAT1',
#   'TCEA2',
#   'TAX1BP3',
#   'PLA2G2A',
#   'PLEKHM1',
#   'LGALS8',
#   'VCAM1',
#   'SYNE1',
#   'LGALS1',
#   'SAMSN1',
#   'IGJ',
#   'HIST1H1C',
#   'RAB11FIP1',
#   'NMU',
#   'ALOX5',
#   'TMEM176B',
#   'IL2RG',
#   'CASP1',
#   'LMO4',
#   'RIN2',
#   'SOX9',
#   'EMP2',
#   'PSMB9',
#   'LPAR6',
#   'CDC42',
#   'EFHD2',
#   'CD53',
#   'RPS11',
#   'AUTS2',
#   'GIMAP6',
#   'HS3ST1',
#   'CECR1',
#   'NID2',
#   'RASGRP1',
#   'LGR5',
#   'CEP55',
#   'TFF1',
#   'CORO1A',
#   'ABAT',
#   'MRPS10',
#   'ELF3',
#   'CPSF4',
#   'GYG1',
#   'ODC1',
#   'SOX4',
#   'FYB',
#   'KAZN',
#   'DPYD',
#   'PLOD2',
#   'NAGK',
#   'IGHD',
#   'ALDH1A1',
#   'GLI2',
#   'RFTN1',
#   'GPX2',
#   'ARHGDIB',
#   'IQGAP2',
#   'AURKB',
#   'FPR1',
#   'HCLS1',
#   'NDUFA4L2',
#   'TIMM8B',
#   'DPP4',
#   'SPINK2',
#   'YWHAE',
#   'PGF',
#   'PLS3',
#   'RAC2',
#   'HEG1',
#   'HIST1H2AC',
#   'ANXA6',
#   'MMP9',
#   'FBN2',
#   'BMI1',
#   'HSPB8',
#   'MS4A6A',
#   'IL32',
#   'MLF1IP',
#   'DACH1',
#   'LCP2',
#   'CD24',
#   'SLA',
#   'UPP1',
#   'AOAH',
#   'RNF167',
#   'RPL38',
#   'ACTN4',
#   'C3AR1',
#   'SLC16A3',
#   'SRRM2',
#   'CFB',
#   'NRIP1',
#   'SLC16A7',
#   'ZNF395',
#   'PLEKHJ1',
#   'COL5A1',
#   'PTPRC',
#   'PROSC',
#   'SUPV3L1',
#   'OLFML2A',
#   'WIPF1',
#   'FRMD4B',
#   'FUCA1',
#   'BCL2'],
#  'HOG002_A549_24H:BRD-K71879491-001-22-6:0.0045': ['LIF',
#   'HSPA6',
#   'HSPA4',
#   'CKM',
#   'CLMN',
#   'CD36',
#   'OPHN1',
#   'C5AR1',
#   'TULP4',
#   'TNNC2',
#   'MYL1',
#   'SLC25A16',
#   'S100A12',
#   'LEF1',
#   'SGPL1',
#   'RBPJ',
#   'NCF4',
#   'EIF1AY',
#   'APBB2',
#   'MAGEA6',
#   'STK24',
#   'HLA-DPA1',
#   'PTP4A2',
#   'PPP6C',
#   'C13ORF15',
#   'MSMB',
#   'IFITM3',
#   'TTN',
#   'CDKN2A',
#   'DDX3Y',
#   'PRRC2C',
#   'ALOX5',
#   'ENPP2',
#   'IFI30',
#   'MUC4',
#   'CHP',
#   'LDB3',
#   'FLRT2',
#   'KLK6',
#   'FGFR4',
#   'SF1',
#   'PPPDE1',
#   'KLHL9',
#   'FN1',
#   'MLF1IP',
#   'SLC2A3',
#   'H2AFZ',
#   'ENC1',
#   'KDM5D',
#   'PDZK1',
#   'RPL37A',
#   'ZWINT',
#   'RPL27A',
#   'C18ORF1',
#   'FCN1',
#   'GLUL',
#   'HDC',
#   'TRIB2',
#   'CHL1',
#   'COL3A1',
#   'PAGE4',
#   'KIAA0922',
#   'VPREB3',
#   'ATP7B',
#   'TNNT1',
#   'SRSF6',
#   'SLC11A2',
#   'SOX11',
#   'NRGN',
#   'CAP2',
#   'NPC2',
#   'FBXL12',
#   'CEACAM5',
#   'NGRN',
#   'NR1H2',
#   'REG3A',
#   'EPHB2',
#   'DALRD3',
#   'RNPS1',
#   'PDLIM3',
#   'HOXB2',
#   'CPA3',
#   'IGFBP2',
#   'MME',
#   'VEGFA',
#   'SMYD2',
#   'FCER1A',
#   'COL16A1',
#   'EIF4B',
#   'C9ORF16',
#   'LRIG1',
#   'MB',
#   'SH3TC1',
#   'TNFAIP3',
#   'MEF2C',
#   'TPSAB1',
#   'CRIP1',
#   'ITGAE',
#   'EIF4A3',
#   'ACP5',
#   'ACTN2',
#   'RAD23B',
#   'BACH2',
#   'ZNF238',
#   'MKNK2',
#   'MKNK1',
#   'EPHA3',
#   'SH3BP4',
#   'SPRY2',
#   'RPS5',
#   'HMGN4',
#   'FBXO7',
#   'VDAC1',
#   'CD9',
#   'MYCL1',
#   'CLEC5A',
#   'SET',
#   'NUSAP1',
#   'TBC1D4',
#   'MRPS30',
#   'IGHM',
#   'S100A9',
#   'HNRNPL',
#   'GGH',
#   'HMGCS2',
#   'HLA-DQB1',
#   'POMP',
#   'SIAH2',
#   'PCDH9',
#   'ZFP36L1',
#   'PLCL1',
#   'LGALS8',
#   'SERPINF1',
#   'LGALS3',
#   'FADS3',
#   'RAD51C',
#   'SLC27A2',
#   'TPSB2',
#   'PCLO',
#   'ACPP',
#   'ANKRD27',
#   'BPIFA1',
#   'FGL2',
#   'USP9Y',
#   'COL1A2',
#   'NKX3-1',
#   'C1QTNF3',
#   'STEAP1',
#   'CDC42',
#   'CD52',
#   'SAT1',
#   'RPS11',
#   'AUTS2',
#   'LPPR1',
#   'LCN2',
#   'HMGB2',
#   'VCAN',
#   'S100P',
#   'TFF3',
#   'RAB2A',
#   'FOXO1',
#   'AP3S1',
#   'IKBKAP',
#   'SPRR1A',
#   'MAGEA3',
#   'HLA-DQA1',
#   'BIN1',
#   'ODC1',
#   'GCHFR',
#   'PAPSS1',
#   'SERPINA1',
#   'BIK',
#   'PLEKHF2',
#   'RGL1',
#   'BID',
#   'SCGB1D2',
#   'GCLC',
#   'PRR7',
#   'FKSG49',
#   'RGS2',
#   'MNDA',
#   'MTA1',
#   'HSD11B1',
#   'HEATR1',
#   'LSM5',
#   'PRKCB',
#   'C6ORF62',
#   'MTSS1',
#   'PPP3CA',
#   'CLC',
#   'PAPOLA',
#   'SNRPE',
#   'RPL14',
#   'TCL1A',
#   'TBL1X',
#   'RPL38',
#   'TXN',
#   'CFB',
#   'CYB5A',
#   'RPA3',
#   'PTPRD',
#   'G3BP1',
#   'MMP9',
#   'ABCC4',
#   'TGFBI',
#   'COL6A3',
#   'BCL6',
#   'FUCA1'],
#  'NMH002_NEU_24H:BRD-K71879491-001-29-1:10': ['PTGS1',
#   'IFRD2',
#   'SFTPB',
#   'WWP1',
#   'IFI27',
#   'NQO1',
#   'CASP10',
#   'GPM6A',
#   'RCBTB2',
#   'SYNE1',
#   'S100A10',
#   'APLP2',
#   'NKX2-1',
#   'FBLN5',
#   'DCN',
#   'PEBP1',
#   'IER5',
#   'RGS5',
#   'CD48',
#   'SFTPC',
#   'CIAPIN1',
#   'EIF1AY',
#   'NTRK2',
#   'PYGB',
#   'PERP',
#   'GOLGA4',
#   'KLK10',
#   'DIO1',
#   'RNASE1',
#   'RBPMS',
#   'TRIM29',
#   'EXT1',
#   'AQP1',
#   'TMF1',
#   'SYNJ2',
#   'HOXD1',
#   'CENPA',
#   'FLRT3',
#   'ABLIM1',
#   'TSPAN4',
#   'TMEM176B',
#   'GATA6',
#   'RFNG',
#   'MS4A4A',
#   'HBB',
#   'USP34',
#   'GATA3',
#   'NME1',
#   'KCTD12',
#   'AKAP1',
#   'FN1',
#   'GALNT6',
#   'MYLK',
#   'CPB1',
#   'SFN',
#   'IFT57',
#   'COLEC12',
#   'ENC1',
#   'GRB7',
#   'CCL19',
#   'KDELR2',
#   'ZBTB20',
#   'C19ORF2',
#   'YBX1',
#   'CPS1',
#   'ANKRD57',
#   'RRAD',
#   'NFKBIB',
#   'VSIG4',
#   'OLFM4',
#   'SYNC',
#   'NDNF',
#   'C1QB',
#   'MED6',
#   'RNH1',
#   'GUCY1A3',
#   'PNMA1',
#   'COL3A1',
#   'MTDH',
#   'KLHDC2',
#   'SERPINE2',
#   'PHLDA2',
#   'GDF15',
#   'C4BPA',
#   'TIMELESS',
#   'CETN2',
#   'ZBTB38',
#   'MALL',
#   'FAM129A',
#   'PSMG1',
#   'HEG1',
#   'TOP2A',
#   'IGF1',
#   'DPYSL3',
#   'METRN',
#   'IGFBP2',
#   'CSRP1',
#   'RHOH',
#   'IGFBP6',
#   'IGFBP7',
#   'ZNF586',
#   'POLR2L',
#   'AKR7A2',
#   'LAMC1',
#   'POLR2I',
#   'PBK',
#   'CR2',
#   'IL13RA2',
#   'ABCG2',
#   'HOPX',
#   'DSTN',
#   'SDC1',
#   'UBE2C',
#   'KLK6',
#   'CDC20',
#   'SCAF4',
#   'MELK',
#   'ZNF551',
#   'MGP',
#   'HLF',
#   'VWF',
#   'BAG3',
#   'FILIP1L',
#   'CCDC109B',
#   'PTPLA',
#   'CLDN18',
#   'EPHA3',
#   'BMP2',
#   'C20ORF103',
#   'RNPEP',
#   'RHOB',
#   'TXNIP',
#   'GPRC5A',
#   'AKR1C1',
#   'AKR1C2',
#   'AKR1C3',
#   'NCOA3',
#   'SCGB1A1',
#   'TRBC1',
#   'CD55',
#   'FBXO21',
#   'C1QBP',
#   'IFI16',
#   'FHL1',
#   'TSEN2',
#   'DUSP5',
#   'S100A6',
#   'C7',
#   'CADM1',
#   'GINS2',
#   'ZBED2',
#   'LAMA3',
#   'ELN',
#   'PHACTR2',
#   'CKS2',
#   'RPS6KA2',
#   'TMEM147',
#   'HN1L',
#   'LAMP3',
#   'UNG',
#   'CLU',
#   'EBNA1BP2',
#   'SLC27A2',
#   'TMEM63A',
#   'DFNA5',
#   'LAPTM4B',
#   'SLC22A18',
#   'GTF2H2B',
#   'KPNA2',
#   'ID4',
#   'LMO3',
#   'PRDX4',
#   'HN1',
#   'MET',
#   'FRMD4B',
#   'COL1A2',
#   'GPNMB',
#   'KIAA1199',
#   'OXTR',
#   'UGT2B28',
#   'AMIGO2',
#   'RIPK4',
#   'MAD2L1',
#   'IPO13',
#   'DHFR',
#   'BIRC5',
#   'CEP55',
#   'EIF5',
#   'MINA',
#   'NRIP1',
#   'SLCO1B3',
#   'CORO1A',
#   'MAP7',
#   'GUSBP3',
#   'PTGDS',
#   'MAGEA3',
#   'ELF3',
#   'ODC1',
#   'DERA',
#   'DDX3Y',
#   'PGC',
#   'LYPD1',
#   'UBQLN2',
#   'PHLDA1',
#   'TM4SF1',
#   'MYH11',
#   'PTHLH',
#   'MAGEA6',
#   'HSPD1',
#   'DUOX2',
#   'SPTBN1',
#   'LPCAT1',
#   'MSLN',
#   'DAPK1',
#   'YWHAE',
#   'PDGFC',
#   'HEATR2',
#   'ANXA4',
#   'CD44',
#   'CD47',
#   'HSPB8',
#   'CYBA',
#   'MCM2',
#   'TNFRSF11B',
#   'RHOBTB1',
#   'TRIP13',
#   'GTPBP8',
#   'MTERFD1',
#   'CCNB2',
#   'CCNB1',
#   'PARD3',
#   'PTGIS',
#   'C1ORF106',
#   'CFI',
#   'FEZ1',
#   'MXI1',
#   'CD163',
#   'SLC16A4',
#   'CALU',
#   'DKK1',
#   'TYMS',
#   'ESRP1',
#   'KIAA0754',
#   'C3ORF37',
#   'CAMK2N1',
#   'MMP1'],
#  'ERG005_VCAP_48H:BRD-K71879491-001-17-6:1': ['ELANE',
#   'FAM198B',
#   'FXYD2',
#   'HBD',
#   'N4BP2L1',
#   'SERPINB1',
#   'S100A11',
#   'DAB2',
#   'BICC1',
#   'MS4A3',
#   'SPINT2',
#   'TFAP2A',
#   'ASB9',
#   'ARHGEF3',
#   'DYNLT3',
#   'HSP90AB1',
#   'MARCKS',
#   'CDH2',
#   'PRTN3',
#   'C5ORF13',
#   'CBLB',
#   'ARHGEF12',
#   'RNASE2',
#   'OIP5',
#   'ERBB4',
#   'ENPP4',
#   'HOXD1',
#   'CTSG',
#   'POSTN',
#   'BAMBI',
#   'ATP2B1',
#   'GATA2',
#   'FAM65B',
#   'OSBPL11',
#   'H2AFV',
#   'RBBP8',
#   'CHN2',
#   'APP',
#   'PKIG',
#   'SLC2A3',
#   'PKIA',
#   'AZU1',
#   'TLR4',
#   'STC1',
#   'FCAR',
#   'PGK1',
#   'TNFSF10',
#   'STMN1',
#   'BBOX1',
#   'RPL27A',
#   'ANXA3',
#   'COL3A1',
#   'PHLDA1',
#   'ARL4C',
#   'SRSF5',
#   'C3AR1',
#   'TCTN2',
#   'CPA3',
#   'LIMCH1',
#   'CALCRL',
#   'CETN2',
#   'THBS1',
#   'NID1',
#   'COL13A1',
#   'WSB2',
#   'B4GALT1',
#   'HNMT',
#   'CHEK1',
#   'COL8A1',
#   'FLRT3',
#   'SLC14A1',
#   'DLD',
#   'DSP',
#   'IGFBP2',
#   'LXN',
#   'SCD5',
#   'FCGR2A',
#   'ACTB',
#   'DNAH3',
#   'CR1',
#   'C6ORF62',
#   'SDC1',
#   'TNFAIP6',
#   'SDC4',
#   'APITD1',
#   'SLC22A4',
#   'HLF',
#   'TRIM2',
#   'IL17RB',
#   'KRT19',
#   'KRT18',
#   'H1FX',
#   'ZNF238',
#   'PAX2',
#   'SMC4',
#   'TBX2',
#   'RPL37A',
#   'SRGN',
#   'RNASET2',
#   'ST6GALNAC5',
#   'AKR1C3',
#   'TICAM1',
#   'SET',
#   'ALCAM',
#   'PNO1',
#   'PTX3',
#   'CKS1B',
#   'PSMA2',
#   'TRMT5',
#   'TFPI',
#   'DDB2',
#   'TGM4',
#   'SEC22B',
#   'ZFP36L1',
#   'MRPS18B',
#   'CLC',
#   'ENO1',
#   'LGALS8',
#   'LAMP3',
#   'CLU',
#   'LRP2',
#   'PROSC',
#   'MYL12B',
#   'PSPH',
#   'GSTM2',
#   'GSTM3',
#   'APOBEC3A',
#   'RIN2',
#   'SOX9',
#   'ABCA1',
#   'PDE4B',
#   'AMIGO2',
#   'CDC42',
#   'RNASE1',
#   'RPS11',
#   'SLC3A1',
#   'MT2A',
#   'LAPTM4B',
#   'MPO',
#   'VCAN',
#   'EIF5',
#   'MEGF9',
#   'LEPREL1',
#   'SAMSN1',
#   'CXCL11',
#   'PRKX',
#   'AQP3',
#   'TXN',
#   'DPYD',
#   'RGL1',
#   'NEFL',
#   'TM4SF1',
#   'OPHN1',
#   'RGS4',
#   'AURKB',
#   'DOK5',
#   'MNDA',
#   'ALOX5',
#   'CDC5L',
#   'PDGFC',
#   'KCNJ16',
#   'HEATR1',
#   'CD47',
#   'FCGR2C',
#   'PLAT',
#   'CES2',
#   'EVI2A',
#   'UCP2',
#   'ATP1B1',
#   'NRP1',
#   'CPVL',
#   'CCNB2',
#   'RPL38',
#   'CA2',
#   'PPP2R2B',
#   'NRIP1',
#   'DKK1',
#   'TYMS',
#   'ACTL6A',
#   'CRIM1',
#   'FOLR1',
#   'TGIF1'],
#  'NMH002_NPC_6H:BRD-K71879491-001-30-9:10': ['RANGRF',
#   'NADK',
#   'PTGS1',
#   'TM4SF1',
#   'TMOD1',
#   'TSPAN4',
#   'KCNE4',
#   'KLK12',
#   'IDI1',
#   'TSPAN12',
#   'CD34',
#   'SCO2',
#   'APOC1',
#   'TSPAN8',
#   'PPP1R3C',
#   'C1ORF116',
#   'STUB1',
#   'FAM114A1',
#   'MICAL2',
#   'C12ORF29',
#   'HBD',
#   'MYC',
#   'RNASE1',
#   'TYRP1',
#   'AQP3',
#   'DFFB',
#   'CD24',
#   'RBP1',
#   'KLK2',
#   'KLK3',
#   'SLC25A24',
#   'SH3BGRL',
#   'ACPP',
#   'CXCL13',
#   'PMEL',
#   'SERPINB6',
#   'FN1',
#   'SNRPD1',
#   'DR1',
#   'KIF5B',
#   'CCND2',
#   'TFPI2',
#   'SFN',
#   'ATP8B1',
#   'NPY',
#   'ENC1',
#   'MAF',
#   'CSRP1',
#   'PID1',
#   'PLAGL1',
#   'CTPS',
#   'CD1C',
#   'ATP2A2',
#   'ALDH3A2',
#   'CDKN1B',
#   'QSOX1',
#   'POLR3K',
#   'CELF2',
#   'PPOX',
#   'BCHE',
#   'PHLDA1',
#   'PHLDA2',
#   'NEBL',
#   'EGR2',
#   'LIMCH1',
#   'CETN3',
#   'QPCT',
#   'S100A14',
#   'GUCY1A3',
#   'CEACAM5',
#   'CEACAM6',
#   'RNPS1',
#   'PDLIM3',
#   'FRZB',
#   'EID1',
#   'EPN2',
#   'COL4A6',
#   'HBE1',
#   'MANSC1',
#   'KIAA0753',
#   'HOPX',
#   'PEX7',
#   'ESR1',
#   'CALML3',
#   'TNFAIP3',
#   'GPX1',
#   'CAMK1',
#   'ITM2A',
#   'SLC22A3',
#   'GNAL',
#   'HES1',
#   'EIF4A1',
#   'EFNB2',
#   'SESN1',
#   'KLHL23',
#   'ITGB7',
#   'SPRY2',
#   'ME1',
#   'CD9',
#   'CHMP5',
#   'MLF1',
#   'TRBC1',
#   'NOTCH2NL',
#   'DNAJB1',
#   'TPSAB1',
#   'GRIA2',
#   'REEP1',
#   'DUSP4',
#   'DUSP7',
#   'PARVA',
#   'DPM3',
#   'TCF21',
#   'WTAP',
#   'CLIC1',
#   'GNB1',
#   'COMT',
#   'LDLR',
#   'ADO',
#   'HPGDS',
#   'TSPO',
#   'TAGLN2',
#   'NOL3',
#   'PDZRN3',
#   'DICER1',
#   'LRIG1',
#   'GALNT11',
#   'TACC2',
#   'MB',
#   'TDG',
#   'PPIH',
#   'GPM6B',
#   'CD52',
#   'FAM115A',
#   'AUTS2',
#   'HS3ST1',
#   'WT1',
#   'FOXG1',
#   'ECM1',
#   'MAP2K3',
#   'FILIP1L',
#   'MAP7',
#   'MAGEA3',
#   'PRSS8',
#   'ANKRD10',
#   'XBP1',
#   'QKI',
#   'KLF10',
#   'YWHAE',
#   'UBQLN2',
#   'VPS28',
#   'PHACTR2',
#   'ICA1',
#   'PFKP',
#   'RGS4',
#   'RAI2',
#   'DNAJC12',
#   'EIF5A',
#   'MBP',
#   'MTA1',
#   'LDHB',
#   'AMD1',
#   'TRAF5',
#   'LTBP1',
#   'PRKCB',
#   'GTF2H5',
#   'SUCLG2',
#   'GTPBP4',
#   'SLK',
#   'DACH1',
#   'IGHM',
#   'NCK1',
#   'GULP1',
#   'IER5',
#   'YRDC',
#   'NOTCH2',
#   'PTPRE',
#   'ABCC4',
#   'TARP',
#   'MLPH'],
#  'HOG002_MCF7_6H:BRD-K71879491-001-22-6:3.3333': ['SMARCC1',
#   'UBE2J1',
#   'MYH11',
#   'ZFPM2',
#   'MLEC',
#   'CPD',
#   'CD36',
#   'CHSY1',
#   'PODXL',
#   'OSBPL1A',
#   'ASB13',
#   'FBP1',
#   'ATP9A',
#   'FBLN1',
#   'POLR3K',
#   'FHIT',
#   'CERS6',
#   'NES',
#   'BHLHE41',
#   'GRK5',
#   'CACNA1D',
#   'DHRS3',
#   'INPP4A',
#   'EAF2',
#   'TCN1',
#   'BIK',
#   'MYC',
#   'C13ORF15',
#   'CTSH',
#   'LYN',
#   'PIK3R1',
#   'PLBD1',
#   'AQP1',
#   'TSC22D3',
#   'DOK5',
#   'CTSE',
#   'CREB1',
#   'ATP1B1',
#   'BAMBI',
#   'LPL',
#   'BGN',
#   'PROM1',
#   'VPS13D',
#   'NQO1',
#   'FGFR3',
#   'DNAJA3',
#   'AKAP1',
#   'CX3CR1',
#   'POU2AF1',
#   'SCARB2',
#   'ARID1A',
#   'RBM47',
#   'OLFM1',
#   'CPB1',
#   'SRPX',
#   'SPEN',
#   'ELK3',
#   'VTCN1',
#   'PRSS21',
#   'TLR4',
#   'BST2',
#   'ALB',
#   'NETO2',
#   'TNNC1',
#   'ARHGAP32',
#   'EMCN',
#   'SKAP2',
#   'RARRES2',
#   'KRT4',
#   'MX2',
#   'MGST2',
#   'TNFRSF17',
#   'FTH1',
#   'EDNRB',
#   'MAFB',
#   'EXOSC4',
#   'TNNT1',
#   'PTN',
#   'NEBL',
#   'CPA3',
#   'LIMCH1',
#   'MEIS2',
#   'MEIS1',
#   'AKR1C1',
#   'CLDN8',
#   'HOXB2',
#   'NID1',
#   'HOXA4',
#   'GCC2',
#   'SCNN1A',
#   'TNS3',
#   'FNDC3B',
#   'AKR1C3',
#   'HIRA',
#   'HNMT',
#   'KLF11',
#   'FRZB',
#   'MN1',
#   'FAM198B',
#   'TEK',
#   'COL4A3',
#   'GPR116',
#   'ZNF589',
#   'MPZL2',
#   'ITPR1',
#   'ARHGEF3',
#   'ZBTB16',
#   'DEPTOR',
#   'PLSCR3',
#   'LRIG1',
#   'TNS1',
#   'DDR2',
#   'SDC1',
#   'SDC4',
#   'GABRP',
#   'TNFAIP2',
#   'MEF2C',
#   'CBS',
#   'MGP',
#   'ANPEP',
#   'RNF128',
#   'GAS1',
#   'GPD1L',
#   'GFPT2',
#   'IL17RB',
#   'KRT19',
#   'MYH10',
#   'EPHX1',
#   'PDGFRA',
#   'FAP',
#   'DEFB1',
#   'CYP4B1',
#   'CD93',
#   'SMAD3',
#   'TBX3',
#   'FABP4',
#   'PRKAR2B',
#   'OLFM4',
#   'KIAA0101',
#   'LUM',
#   'AKR1C2',
#   'GPRC5B',
#   'AKR1B10',
#   'CYP1B1',
#   'BTG2',
#   'MECOM',
#   'ASPN',
#   'C6ORF108',
#   'NR2F1',
#   'C5AR1',
#   'TPSAB1',
#   'SCPEP1',
#   'DUSP4',
#   'SRD5A1',
#   'PBX1',
#   'SEL1L',
#   'LAMA3',
#   'PELI1',
#   'SRI',
#   'SULT1A1',
#   'ZFP36L1',
#   'GPR64',
#   'GOLM1',
#   'TPD52L1',
#   'CLU',
#   'HEY2',
#   'ABCD3',
#   'SLPI',
#   'TPSB2',
#   'SFRP1',
#   'RGS13',
#   'SFRP4',
#   'WWTR1',
#   'MSLN',
#   'LMO2',
#   'MB',
#   'LMO4',
#   'RARRES3',
#   'RARRES1',
#   'EPB41L3',
#   'AZGP1',
#   'HOXA5',
#   'ERG',
#   'ATP1A2',
#   'ABCA1',
#   'PLN',
#   'ZMIZ1',
#   'PSCA',
#   'PPIB',
#   'CFD',
#   'DPT',
#   'SVIL',
#   'IPO13',
#   'HMOX1',
#   'VCAN',
#   'SPARCL1',
#   'RBPMS',
#   'FOXO3',
#   'FOXO1',
#   'TSKU',
#   'MAGEA3',
#   'ELF3',
#   'CDC20',
#   'NDRG2',
#   'ALDH1A3',
#   'SEL1L3',
#   'LPHN2',
#   'SERTAD2',
#   'PAPSS2',
#   'RAP1GAP',
#   'MAOB',
#   'BID',
#   'TM4SF1',
#   'GCLC',
#   'ALDH1A1',
#   'ETS2',
#   'RGS5',
#   'IGJ',
#   'RPIA',
#   'SLIT2',
#   'KCNS3',
#   'RYBP',
#   'JAG1',
#   'DAAM2',
#   'C1ORF38',
#   'GREM1',
#   'PDGFD',
#   'LTBP1',
#   'ITGB6',
#   'LSM5',
#   'NMU',
#   'PRKCD',
#   'PLAT',
#   'CES1',
#   'GTPBP4',
#   'IGHD',
#   'RHOBTB1',
#   'CD24',
#   'VWF',
#   'TAGLN',
#   'ATF6',
#   'CHST15',
#   'CFI',
#   'GULP1',
#   'PFKFB3',
#   'COL14A1',
#   'NRIP1',
#   'NOTCH2',
#   'NOTCH3',
#   'GSTP1',
#   'OGN',
#   'ADH1B',
#   'SYBU',
#   'SLC1A4',
#   'KAT6B',
#   'BCL6',
#   'FOLR1',
#   'ARHGEF40'],
#  'ASG001_MCF7_6H:BRD-K71879491-001-17-6:2': ['SSPN',
#   'CCNE1',
#   'ADD3',
#   'SCG5',
#   'FAM3C',
#   'PLBD1',
#   'PDGFRA',
#   'CD36',
#   'TRMT61B',
#   'OSBPL1A',
#   'MFAP4',
#   'CAPRIN2',
#   'MFAP2',
#   'GPM6B',
#   'OGN',
#   'TMOD1',
#   'FBLN1',
#   'HOXB2',
#   'SLC30A1',
#   'SERPINB3',
#   'FBLN5',
#   'DCN',
#   'COL1A1',
#   'DENND2D',
#   'BHLHE41',
#   'EIF1AX',
#   'DHRS3',
#   'LYZ',
#   'MAP3K5',
#   'C20ORF103',
#   'NAV3',
#   'ZC3H15',
#   'SRPX2',
#   'MYC',
#   'VTCN1',
#   'CTSK',
#   'SLC38A1',
#   'PBX1',
#   'PRRC2C',
#   'TSC22D3',
#   'CTSC',
#   'ATP1B1',
#   'BAMBI',
#   'LPL',
#   'ABLIM1',
#   'TMEM176B',
#   'SNAI2',
#   'CXCL13',
#   'SERPINB2',
#   'CXCL14',
#   'EMILIN1',
#   'OMD',
#   'ACSL3',
#   'ISLR',
#   'ACSL1',
#   'SRPX',
#   'EGFL6',
#   'DYRK2',
#   'PLTP',
#   'SMPX',
#   'LXN',
#   'NETO2',
#   'GOLGA8B',
#   'LPHN2',
#   'UGCG',
#   'MMP11',
#   'ATP2A2',
#   'SKAP2',
#   'HSP90B1',
#   'NPTX1',
#   'PTGDS',
#   'ACSL5',
#   'KLHDC2',
#   'XIST',
#   'APOD',
#   'GATA6',
#   'ITGB6',
#   'CTGF',
#   'MEIS1',
#   'FRZB',
#   'CDK5R1',
#   'SCNN1A',
#   'HTR2B',
#   'ITGBL1',
#   'TOP2B',
#   'IGF1',
#   'DPYSL3',
#   'PDLIM3',
#   'EFEMP1',
#   'RNF144A',
#   'HOXB6',
#   'HOXB7',
#   'PRKCD',
#   'IGFBP3',
#   'IGFBP6',
#   'NELL1',
#   'PLAT',
#   'PDGFRL',
#   'PREPL',
#   'NAA15',
#   'CYP4B1',
#   'LRIG1',
#   'PLSCR1',
#   'LRRC17',
#   'ERMP1',
#   'TNFAIP2',
#   'MEF2C',
#   'MGP',
#   'POLE2',
#   'GAS1',
#   'GPD1L',
#   'LOC100505650',
#   'HOXB5',
#   'SH3YL1',
#   'FAP',
#   'EPHA3',
#   'SCYL3',
#   'SMAD3',
#   'TBX3',
#   'PRKAR2B',
#   'PRPF40A',
#   'KRT5',
#   'TXNIP',
#   'DACT1',
#   'LUM',
#   'GNAI1',
#   'MYH3',
#   'WFDC2',
#   'CYP1B1',
#   'GNL3L',
#   'MPZL1',
#   'MECOM',
#   'ASPN',
#   'NR2F6',
#   'TPM2',
#   'HHEX',
#   'IGHM',
#   'S100A9',
#   'TSEN2',
#   'PDE10A',
#   'DUSP4',
#   'SRD5A1',
#   'DUSP6',
#   'REEP5',
#   'MARCKSL1',
#   'TGFBR2',
#   'ZBED2',
#   'LAMA3',
#   'ELN',
#   'DCX',
#   'TCFL5',
#   'COMP',
#   'ARL6IP5',
#   'EPYC',
#   'TCEA2',
#   'ZFP36L2',
#   'SPARCL1',
#   'SORD',
#   'HOPX',
#   'TPD52L2',
#   'VCAM1',
#   'TPD52L1',
#   'DLEU1',
#   'PDZRN3',
#   'SLPI',
#   'SFRP1',
#   'GALNT12',
#   'SFRP4',
#   'C2ORF28',
#   'C7',
#   'LMO3',
#   'LMO4',
#   'IRS1',
#   'RARRES1',
#   'WDR12',
#   'HOXA5',
#   'HOXA4',
#   'HOXA1',
#   'GDPD5',
#   'S100A6',
#   'F2RL1',
#   'PPIC',
#   'COL10A1',
#   'EPB41L1',
#   'DPT',
#   'MORC4',
#   'VCAN',
#   'EIF5',
#   'ECM1',
#   'FOXO3',
#   'NFYB',
#   'TSKU',
#   'MAP7',
#   'SLC5A6',
#   'MOXD1',
#   'SPATS2L',
#   'ELF3',
#   'ANKRD12',
#   'ALDH1A3',
#   'SEL1L3',
#   'CILP',
#   'RAP1GAP',
#   'CRABP2',
#   'LPIN1',
#   'EIF5B',
#   'PDE1A',
#   'TM4SF1',
#   'ANK2',
#   'RND3',
#   'TATDN2',
#   'ETS2',
#   'KLF5',
#   'NNMT',
#   'TNNI2',
#   'SLIT2',
#   'RGS2',
#   'ECM2',
#   'HOMER3',
#   'PCMTD2',
#   'LTBP2',
#   'HEATR1',
#   'NMU',
#   'TMPRSS4',
#   'SRSF7',
#   'PTGIS',
#   'FBN1',
#   'LGALS3BP',
#   'ST6GALNAC5',
#   'CD24',
#   'TPSAB1',
#   'WASF1',
#   'VAMP1',
#   'CHST15',
#   'CFH',
#   'B4GALT5',
#   'GULP1',
#   'C1QTNF3',
#   'COL14A1',
#   'NRIP1',
#   'PSAT1',
#   'TARBP1',
#   'FLRT2',
#   'CKAP4',
#   'TAC1',
#   'C1S',
#   'C1R',
#   'CAMK2N1',
#   'IFI44',
#   'MMP2',
#   'WDR77',
#   'GOLM1'],
#  'ASG001_PC3_24H:BRD-K71879491-001-17-6:10': ['DHDDS',
#   'PPAP2B',
#   'PPAP2A',
#   'FKBP11',
#   'STK10',
#   'SLC6A8',
#   'AOC3',
#   'CASP10',
#   'ZFAND5',
#   'IGKC',
#   'SLC25A14',
#   'PLVAP',
#   'PECAM1',
#   'CTSS',
#   'PPP1R3C',
#   'DKK3',
#   'DHRS9',
#   'CCL5',
#   'DHRS3',
#   'FSTL1',
#   'INHBA',
#   'MICAL2',
#   'NR4A3',
#   'TAGLN2',
#   'CDH2',
#   'C5ORF13',
#   'C2CD2',
#   'DDIT4',
#   'PLBD1',
#   'COG2',
#   'CD27',
#   'MRPS2',
#   'LEFTY1',
#   'KCNAB1',
#   'TNIP1',
#   'PI3',
#   'TNS1',
#   'CDA',
#   'CXCL1',
#   'BRP44',
#   'IGKV1-5',
#   'FN1',
#   'POU2AF1',
#   'LITAF',
#   'VIM',
#   'SFN',
#   'ANGPTL4',
#   'DIXDC1',
#   'STC1',
#   'PLAGL1',
#   'SLC19A2',
#   'LGR5',
#   'NPY1R',
#   'VLDLR',
#   'PRKCH',
#   'ALDH3A2',
#   'CDKN1A',
#   'HSPG2',
#   'ITGA4',
#   'RNH1',
#   'EDNRA',
#   'EDNRB',
#   'VPREB3',
#   'TGFA',
#   'ZNF451',
#   'S100A12',
#   'DACT1',
#   'LIMCH1',
#   'JUN',
#   'MEIS2',
#   'QPCT',
#   'NCAM1',
#   'SEMA4C',
#   'MALL',
#   'CEACAM5',
#   'CEACAM6',
#   'PJA1',
#   'CCL20',
#   'GDF15',
#   'PLEK2',
#   'SMC1A',
#   'PDLIM5',
#   'C10ORF116',
#   'FRZB',
#   'OLFM4',
#   'IGL@',
#   'PMEPA1',
#   'PRKCD',
#   'HCAR3',
#   'IGFBP3',
#   'PPARD',
#   'AKR1B10',
#   'VEGFA',
#   'IGFBP7',
#   'COL4A1',
#   'LAMC2',
#   'RHOB',
#   'SCRN1',
#   'ITPR1',
#   'TUBB2A',
#   'APOLD1',
#   'CSGALNACT1',
#   'C10ORF10',
#   'EPAS1',
#   'HOPX',
#   'TNFAIP8',
#   'GSTT1',
#   'IVL',
#   'RBPMS',
#   'TNFAIP3',
#   'TNFAIP2',
#   'IGLJ3',
#   'ITM2A',
#   'TRDV3',
#   'CREM',
#   'GPC4',
#   'FLNB',
#   'CRIP1',
#   'COL4A2',
#   'MKNK2',
#   'ACTC1',
#   'SMAD7',
#   'KIAA1462',
#   'STOM',
#   'ATP5H',
#   'DLK1',
#   'REL',
#   'COX7A1',
#   'IL1A',
#   'IL1B',
#   'GLS',
#   'GPRC5A',
#   'AKR1C1',
#   'AKR1C2',
#   'AKR1C3',
#   'RPS4Y1',
#   'SIK1',
#   'BTG2',
#   'POLR2I',
#   'H1FX',
#   'MOCOS',
#   'C17ORF101',
#   'CFLAR',
#   'SPARC',
#   'ICAM1',
#   'FOSL2',
#   'GZMK',
#   'S100A7',
#   'CST6',
#   'COCH',
#   'ELANE',
#   'ZNF423',
#   'SEPW1',
#   'GJA1',
#   'UGDH',
#   'CSTA',
#   'CHRDL1',
#   'MCAM',
#   'ENO1',
#   'CCND2',
#   'MAST4',
#   'MXRA7',
#   'BBX',
#   'CD8A',
#   'LGALS1',
#   'UCHL1',
#   'PTBP1',
#   'SEMA3C',
#   'ACPP',
#   'LRRFIP1',
#   'LRP4',
#   'FAM20B',
#   'MTF2',
#   'ID1',
#   'HN1',
#   'NMB',
#   'ISG20',
#   'PLN',
#   'COL8A2',
#   'HAPLN1',
#   'LDLRAP1',
#   'SETBP1',
#   'C7ORF68',
#   'MKI67',
#   'BPGM',
#   'LCN2',
#   'S100P',
#   'CYB5A',
#   'MRPS16',
#   'CRCT1',
#   'IGLL3P',
#   'AEBP1',
#   'LEPREL1',
#   'ZC3H12A',
#   'SORBS2',
#   'SPRR1B',
#   'SEMA6A',
#   'SEL1L3',
#   'LPHN2',
#   'SERTAD2',
#   'KIAA0485',
#   'AXIN1',
#   'NDN',
#   'PLCXD1',
#   'RAB38',
#   'KLF7',
#   'RGS5',
#   'IGJ',
#   'RPIA',
#   'KLF2',
#   'SLC35E1',
#   'TCF4',
#   'HOMER2',
#   'PDE2A',
#   'XIST',
#   'DNMT3A',
#   'RAC2',
#   'LTBP2',
#   'ITGB6',
#   'NR4A2',
#   'CD44',
#   'CA12',
#   'SLC25A6',
#   'MAP7D1',
#   'PPP1R12B',
#   'FPGS',
#   'IGHM',
#   'NDUFA4L2',
#   'SQSTM1',
#   'C1ORF106',
#   'LTB',
#   'PFKFB3',
#   'COL14A1',
#   'NRIP1',
#   'RPA3',
#   'PON2',
#   'GSTP1',
#   'SOX11',
#   'TGFBI',
#   'HLA-DQA1'],
#  'ASG001_MCF7_6H:BRD-K71879491-001-17-6:0.08': ['MAN2B1',
#   'SCG5',
#   'CPD',
#   'BGN',
#   'NQO1',
#   'RAPGEF5',
#   'CHN1',
#   'MFAP4',
#   'UBE2G1',
#   'IGKC',
#   'ASS1',
#   'SIK1',
#   'PPP1R3C',
#   'SQRDL',
#   'TPD52',
#   'SFTPC',
#   'DHRS3',
#   'GNG12',
#   'PTPLB',
#   'GRWD1',
#   'SFTPA2',
#   'CAPN2',
#   'BIK',
#   'PIR',
#   'FGG',
#   'LOX',
#   'WT1',
#   'SOD2',
#   'SHC1',
#   'TSC22D3',
#   'ATP1B1',
#   'PEX11A',
# ...
#   'SAT1',
#   'SMAD3',
#   'TBX3',
#   'OLFM1',
#   'PRKAR2B',
#   'DLK1',
#   'OLFM4',
#   'PLEKHA4',
#   'SCPEP1',
#   'SEC24C',
#   'CD52',
#   'FASTKD5',
#   'CYP1B1',
#   'NLRP2',
#   'PBX3',
#   'FHL2',
#   'RNASE3',
#   'CES1',
#   'RAB13',
#   'SUCLG2',
#   'COPA',
#   'NDN',
#   'VCAN',
#   'ARL6IP5',
#   'TFPI',
#   'TCEA2',
#   'ZFP36L2',
#   'HMGA1',
#   'PROM1',
#   'SERPINF1',
#   'LTF',
#   'SALL2',
#   'NDP',
#   'KCNJ2',
#   'SEMA3C',
#   'SFRP1',
#   'SFRP4',
#   'MICALL2',
#   'RARRES3',
#   'RARRES1',
#   'GULP1',
#   'CNTNAP2',
#   'STEAP3',
#   'LPAR1',
#   'CDC42',
#   'SEPP1',
#   'PHF15',
#   'EGFR',
#   'SPARCL1',
#   'RBPMS',
#   'MRPS16',
#   'SOX9',
#   'SLC5A6',
#   'ELF1',
#   'LMO3',
#   'ALDH1A3',
#   'SEL1L3',
#   'CYP27A1',
#   'PGD',
#   'KAZN',
#   'CRABP1',
#   'AXIN1',
#   'PRPF19',
#   'AREG',
#   'PLOD1',
#   'NEFH',
#   'IMPDH2',
#   'TATDN2',
#   'ABCB1',
#   'ELTD1',
#   'RGS1',
#   'RGS2',
#   'CXCR4',
#   'HSD17B2',
#   'JAG1',
#   'SPINK2',
#   'LPHN3',
#   'MATN2',
#   'LTBP3',
#   'GLIPR1',
#   'AIM1',
#   'FBN2',
#   'LPHN1',
#   'CLEC11A',
#   'LGALS3BP',
#   'IL33',
#   'FAM102A',
#   'HEPH',
#   'ALDOC',
#   'NRP1',
#   'PBX1',
#   'RAB20',
#   'NFIB',
#   'CRABP2',
#   'NCK2',
#   'CFI',
#   'SLC16A1',
#   'TEX2',
#   'ARMCX3',
#   'NRIP1',
#   'IL17RB',
#   'OGN',
#   'SEC24A',
#   'SCD',
#   'CHST2',
#   'C1R',
#   'TARP'],
#  'ASG001_MCF7_24H:BRD-K71879491-001-17-6:0.08': ['FXYD6',
#   'PPAP2B',
#   'GSTA4',
#   'WNT5A',
#   'BGN',
#   'CHN1',
#   'BAMBI',
#   'ASS1',
#   'DCN',
#   'LHX2',
#   'CALM1',
#   'TPD52',
#   'RAP1GAP2',
#   'DSC2',
#   'CCDC92',
#   'MAP3K5',
#   'INHBA',
#   'PRIM1',
#   'CAPN2',
#   'GLA',
#   'MFAP3L',
#   'PIR',
#   'C5ORF13',
#   'CTNNAL1',
#   'TRIM29',
#   'IDH1',
#   'ATP1B1',
#   'IMPA2',
#   'RPL10',
#   'TPR',
#   'ANXA10',
#   'TSPAN8',
#   'FGFR3',
#   'KRAS',
#   'DBI',
#   'SNAP25',
#   'CXCL3',
#   'STAT1',
#   'CXCL5',
#   'BMP2',
#   'ALDH1L1',
#   'ACSL1',
#   'PKIA',
#   'RAI14',
#   'SOD2',
#   'TNFRSF21',
#   'CPS1',
#   'NFATC3',
#   'ATP6V1A',
#   'MMP11',
#   'CCL4',
#   'SKAP2',
#   'ENAH',
#   'NFKBIA',
#   'NUP85',
#   'ITGA6',
#   'HOXC6',
#   'MFSD10',
#   'KLK2',
#   'NDRG1',
#   'TST',
#   'PGRMC1',
#   'MRFAP1L1',
#   'AKR1C1',
#   'NID2',
#   'PILRB',
#   'PLEKHB2',
#   'PCBP2',
#   'DIO1',
#   'DIO2',
#   'CCL20',
#   'CLDN3',
#   'CHEK2',
#   'CHEK1',
#   'PTPRN2',
#   'PDLIM5',
#   'FOS',
#   'CDC25B',
#   'C3ORF14',
#   'SLC38A1',
#   'HTATIP2',
#   'FCGR2C',
#   'MAGEB2',
#   'PLEC',
#   'DDX60',
#   'CYP1B1',
#   'COL16A1',
#   'GALNT1',
#   'SLC39A6',
#   'CSGALNACT1',
#   'PION',
#   'SDC1',
#   'CDC14B',
#   'INSM1',
#   'KRT17',
#   'MELK',
#   'PFN2',
#   'GOLM1',
#   'ZNF148',
#   'VEGFA',
#   'NOV',
#   'TRIM2',
#   'EIF4A1',
#   'HIST3H2A',
#   'CRIP2',
#   'RALBP1',
#   'DHRS2',
#   'SLC4A4',
#   'OLFM1',
#   'PRPF40A',
#   'RHOB',
#   'FH',
#   'STAR',
#   'DACT1',
#   'PTGES',
#   'AKR1C2',
#   'SIK1',
#   'FZD5',
#   'TMEM14A',
#   'CGA',
#   'TECR',
#   'CFLAR',
#   'PPBP',
#   'PBK',
#   'OBSL1',
#   'DUSP5',
#   'NFKB2',
#   'S100A6',
#   'DUSP1',
#   'HHEX',
#   'DNPEP',
#   'TBXA2R',
#   'LY6D',
#   'COMP',
#   'C6ORF62',
#   'ZFP36L2',
#   'SORD',
#   'MAST2',
#   'CD9',
#   'LAMP2',
#   'CLU',
#   'SLC43A3',
#   'ADAM28',
#   'LGALS4',
#   'MAEA',
#   'CXADR',
#   'FHOD3',
#   'NEAT1',
#   'PSPH',
#   'APOBEC3B',
#   'MYBPC1',
#   'HOXA5',
#   'TMSB15A',
#   'COL1A1',
#   'IL8',
#   'PF4',
#   'IFIH1',
#   'CUTA',
#   'JUNB',
#   'EGFR',
#   'TFF1',
#   'PTPRZ1',
#   'UST',
#   'MCL1',
#   'MYBL1',
#   'F13A1',
#   'LOX',
#   'SORBS2',
#   'COBLL1',
#   'DDX17',
#   'KLF11',
#   'PAPSS2',
#   'TOB1',
#   'SLC37A4',
#   'CBS',
#   'VPS28',
#   'RAB7L1',
#   'NEFH',
#   'MAB21L2',
#   'TATDN2',
#   'CXCR7',
#   'HOMER3',
#   'OGDHL',
#   'CENPE',
#   'SPINK1',
#   'ITGB3',
#   'COPA',
#   'ITGB4',
#   'LTBP1',
#   'NR4A2',
#   'PRKCD',
#   'C8ORF4',
#   'GPC1',
#   'KYNU',
#   'IL32',
#   'NBPF10',
#   'PBX3',
#   'BACE2',
#   'TBL1X',
#   'NRIP1',
#   'NOTCH3',
#   'PSAT1',
#   'RND3',
#   'FAR2',
#   'COL6A1',
#   'PPP3CA',
#   'PICALM',
#   'VCAM1'],
#  'HOG002_A549_6H:BRD-K71879491-001-22-6:3.3333': ['HSPA2',
#   'TIMP3',
#   'KLK10',
#   'POLG2',
#   'LRRC16A',
#   'PDGFRA',
#   'ZFAND6',
#   'AKT3',
#   'GPM6A',
#   'SULF1',
#   'ANP32A',
#   'DCN',
#   'PPP1R3C',
#   'MT1M',
#   'DHRS2',
#   'INPP4B',
#   'DCT',
#   'NUP210',
#   'MTMR1',
#   'RNASE1',
#   'ERBB3',
#   'KLK11',
#   'TRIM28',
#   'DDX3Y',
#   'PLBD1',
#   'KRT23',
#   'MDFIC',
#   'ZNF551',
#   'TPSB2',
#   'CDO1',
#   'CHP',
#   'RPL10',
#   'GPATCH8',
#   'MT1E',
#   'NXN',
#   'BMX',
#   'CXCL1',
#   'CNN3',
#   'SNRPD1',
#   'CXCL6',
#   'TMEM45A',
#   'EEF1D',
#   'CCND2',
#   'TFPI2',
#   'SFN',
#   'MAMLD1',
#   'PLTP',
#   'DOK5',
#   'TLR4',
#   'KDM5D',
#   'TMEM158',
#   'GOLGA8A',
#   'GOLGA8B',
#   'CCL2',
#   'UGCG',
#   'TNFSF10',
#   'EVL',
#   'SLC7A8',
#   'COPS2',
#   'PTPLAD1',
#   'CELF2',
#   'KHDRBS3',
#   'SETBP1',
#   'PDZK1IP1',
#   'NOP16',
#   'EDNRB',
#   'CSDA',
#   'EIF5A',
#   'CHIC2',
#   'APOE',
#   'CHD7',
#   'HAUS7',
#   'JUN',
#   'HOXA5',
#   'QPCT',
#   'PLEKHB1',
#   'GATM',
#   'H3F3B',
#   'TNS3',
#   'CCL20',
#   'MT1F',
#   'MT1G',
#   'NPEPPS',
#   'PDLIM4',
#   'GSPT2',
#   'NHP2L1',
#   'C10ORF116',
#   'RASL11B',
#   'HOXB2',
#   'CPA3',
#   'NUPR1',
#   'NUDT4',
#   'DSP',
#   'RSL1D1',
#   'ZNF586',
#   'ZWILCH',
#   'PELI1',
#   'CSGALNACT1',
#   'GJA1',
#   'CDH19',
#   'LRIG1',
#   'HAT1',
#   'SLC19A2',
#   'TCN1',
#   'PFN2',
#   'MGP',
#   'ITGAM',
#   'SNCA',
#   'TPSAB1',
#   'KRT19',
#   'KIAA0182',
#   'PKM2',
#   'FJX1',
#   'ZNF238',
#   'ZNF22',
#   'EPHA3',
#   'IDS',
#   'EIF1AY',
#   'CNBP',
#   'RPS2',
#   'PLP1',
#   'KIAA0101',
#   'LUM',
#   'NUSAP1',
#   'ZHX2',
#   'PTX3',
#   'NR2F2',
#   'ARPP19',
#   'C13ORF15',
#   'CHPT1',
#   'S100A9',
#   'S100A8',
#   'FGF13',
#   'CITED2',
#   'S100A7',
#   'BSG',
#   'LYST',
#   'KRT14',
#   'COMP',
#   'SPIB',
#   'SERPINF1',
#   'LTF',
#   'LOC728855',
#   'TPD52L1',
#   'SEMA3A',
#   'RAB11FIP1',
#   'SFRP1',
#   'WWTR1',
#   'CST6',
#   'RARRES3',
#   'HN1',
#   'BANF1',
#   'ADRB2',
#   'EMP2',
#   'GPM6B',
#   'PDE4B',
#   'CALR',
#   'IL8',
#   'ST6GAL1',
#   'HMGB3',
#   'TIMM9',
#   'ALOX5AP',
#   'ATP11B',
#   'PAEP',
#   'KIAA1033',
#   'MITF',
#   'SMARCA2',
#   'RPL31',
#   'OTUB1',
#   'YES1',
#   'GPI',
#   'HDGFRP3',
#   'BIK',
#   'WASF3',
#   'ITGB1BP1',
#   'NDN',
#   'LOC100507397',
#   'DDX18',
#   'TLN1',
#   'ELOVL5',
#   'ARHGDIA',
#   'CNOT3',
#   'PYCARD',
#   'USP6NL',
#   'ALOX5',
#   'ST3GAL5',
#   'HEATR1',
#   'KANK1',
#   'CA12',
#   'MT1P2',
#   'MCM6',
#   'SERPINA3',
#   'GPC4',
#   'PTPRO',
#   'TNC',
#   'PBX3',
#   'DHCR24',
#   'NFIB',
#   'VAMP8',
#   'PFKFB3',
#   'NOTCH2',
#   'SLC1A1',
#   'LCN2',
#   'RND3',
#   'DKC1',
#   'SLC1A4',
#   'EAPP',
#   'TARP',
#   'ZNF395'],
#  'ERG005_VCAP_24H:BRD-K71879491-001-17-6:1': ['HIST1H4C',
#   'TRMT112',
#   'ELANE',
#   'TGM4',
#   'SFTPB',
#   'GNPDA1',
#   'SPRED2',
#   'DUSP5',
#   'CXCL11',
#   'SWAP70',
#   'NKX2-1',
#   'ZNF140',
#   'EIF3K',
#   'MBIP',
#   'RBM34',
#   'APBB2',
#   'PSD3',
#   'EAF2',
#   'MARCKS',
#   'SLC12A1',
#   'MEIS3P1',
#   'IRX5',
#   'WEE1',
#   'ST18',
#   'H2BFS',
#   'CBLB',
#   'RNASE3',
#   'RNASE2',
#   'AQP3',
#   'RAB5C',
#   'CXADR',
#   'ENPP4',
#   'TSC22D2',
#   'ENPP2',
#   'CENPA',
#   'ATP1B1',
#   'BAMBI',
#   'LPL',
#   'SERPINB1',
#   'OSBPL3',
#   'IL6ST',
#   'GATA2',
#   'FGFR3',
#   'CEP350',
#   'PTMA',
#   'APP',
#   'SLC2A3',
#   'AZU1',
#   'CEP70',
#   'POP5',
#   'CSRP1',
#   'TRIP4',
#   'CHAC1',
#   'LGR5',
#   'RPL37A',
#   'MMP12',
#   'STMN2',
#   'RPL39L',
#   'RPL27A',
#   'MX2',
#   'NUP85',
#   'MX1',
#   'GOLT1B',
#   'CLTA',
#   'STAC',
#   'TRIB2',
#   'TMEM110',
#   'COL3A1',
#   'EDNRB',
#   'PHLDA1',
#   'ARL4C',
#   'IFIT1',
#   'CHIC2',
#   'BEX1',
#   'CCNE2',
#   'CAP1',
#   'QPCT',
#   'TIAM1',
#   'ISG15',
#   'B4GALT1',
#   'ANGPT1',
#   'CD47',
#   'CHEK1',
#   'MRPL12',
#   'FLRT3',
#   'CCDC56',
#   'ID3',
#   'ERP29',
#   'GBP1',
#   'ARPC4',
#   'HIST1H2BD',
#   'IGFBP3',
#   'COL4A3',
#   'C3ORF14',
#   'POLR2I',
#   'FGF1',
#   'TUBB2B',
#   'IGFBP2',
#   'TMEM14A',
#   'SDC1',
#   'GCH1',
#   'PSAP',
#   'MEIS2',
#   'POLE2',
#   'RNF128',
#   'HES1',
#   'DYNLT3',
#   'KRT19',
#   'CTSZ',
#   'SMAD6',
#   'MYO1B',
#   'C20ORF103',
#   'TBX2',
#   'CD1E',
#   'POLB',
#   'SPRY4',
#   'NEDD9',
#   'TNPO1',
#   'SNX11',
#   'ALCAM',
#   'SNRPG',
#   'PPBP',
#   'NAV2',
#   'GPN1',
#   'FGF13',
#   'DUSP4',
#   'DUSP6',
#   'DLC1',
#   'GGH',
#   'P4HTM',
#   'TBXA2R',
#   'PFDN6',
#   'SMNDC1',
#   'QDPR',
#   'DPH2',
#   'CALB1',
#   'PLEKHM1',
#   'SIGLEC15',
#   'LGALS8',
#   'ADAM23',
#   'GALC',
#   'THY1',
#   'HIST1H1C',
#   'RAB11FIP2',
#   'CST1',
#   'RGS13',
#   'IFI6',
#   'GSTM3',
#   'TBCB',
#   'BASP1',
#   'PRTN3',
#   'PSMB8',
#   'CDK5RAP3',
#   'ARMCX1',
#   'CDC42',
#   'RPS11',
#   'LEPREL1',
#   'SDC4',
#   'AP1S1',
#   'RRM1',
#   'NRIP3',
#   'MYOF',
#   'SOX4',
#   'TXN',
#   'PLBD1',
#   'TAC1',
#   'TM4SF1',
#   'NEFH',
#   'GBE1',
#   'AURKB',
#   'KCNJ16',
#   'HIST1H2AC',
#   'CDC42EP3',
#   'CD44',
#   'LSM6',
#   'UMOD',
#   'C8ORF4',
#   'PLAT',
#   'LGALS3BP',
#   'TP53BP1',
#   'DACH1',
#   'TUBA4A',
#   'UCP2',
#   'CD24',
#   'SNRPF',
#   'RASA1',
#   'ZBTB38',
#   'COX7A2L',
#   'CCNB2',
#   'UPP1',
#   'NGFRAP1',
#   'ARMCX6',
#   'SLC16A3',
#   'NRIP1',
#   'RPA3',
#   'DKK1',
#   'RND3',
#   'KCNK5',
#   'PTPRO',
#   'ATP6V0E1',
#   'IFI44',
#   'FOLR1'],
#  'ERG005_VCAP_6H:BRD-K71879491-001-17-6:5': ['BCL2L1',
#   'ASXL2',
#   'TGM4',
#   'TRIM14',
#   'WWP1',
#   'LYPLA1',
#   'MME',
#   'GNPDA1',
#   'CLMN',
#   'CPE',
#   'SPRED2',
#   'IL6ST',
#   'FKBP4',
#   'TPBG',
#   'OAT',
#   'GLIPR1',
#   'BCAM',
#   'PRPF4',
#   'PDLIM3',
#   'CD27',
#   'BHLHE40',
#   'GATA2',
#   'EIF1AY',
#   'CXCL14',
#   'RAB40B',
#   'GNAL',
#   'ISL1',
#   'IRX5',
#   'HEBP1',
#   'ABHD5',
#   'TWF1',
#   'PLK2',
#   'DDX3X',
#   'TRIM29',
#   'CXADR',
#   'ENPP2',
#   'HOXD1',
#   'ATP1B1',
#   'ASB13',
#   'RBP1',
#   'BAMBI',
#   'LPL',
#   'IFRD2',
#   'ATP2B1',
#   'UBR7',
#   'FGFR3',
#   'WSB2',
#   'SOCS5',
#   'TOR1AIP1',
#   'VEGFA',
#   'AKAP1',
#   'TBX3',
#   'CCND1',
#   'SYT1',
#   'SOCS2',
#   'RUNX1',
#   'NPY',
#   'GRB7',
#   'FKBP1A',
#   'IL7R',
#   'UGCG',
#   'RPL37A',
#   'ANKRD57',
#   'RRAD',
#   'RPL27A',
#   'SPRY4',
#   'SPON1',
#   'DDX3Y',
#   'ID3',
#   'PPOX',
#   'POLR1C',
#   'TRIB2',
#   'PTGDS',
#   'PNMA2',
#   'NCKAP1',
#   'EIF5A',
#   'CHIC2',
#   'PTN',
#   'ADORA2B',
#   'CPA3',
#   'EGR1',
#   'CTGF',
#   'PLEKHB2',
#   'PCLO',
#   'DIO2',
#   'B4GALT1',
#   'CX3CL1',
#   'HNMT',
#   'PDLIM4',
#   'MLF1',
#   'ISCA1',
#   'KIAA1199',
#   'LRIF1',
#   'DST',
#   'COL1A1',
#   'UBE2E1',
#   'SLC24A3',
#   'PDP1',
#   'CCDC6',
#   'SNX13',
#   'CORO2A',
#   'SCGB1A1',
#   'CKLF',
#   'PSCA',
#   'CYP4B1',
#   'POSTN',
#   'SDC1',
#   'ARG2',
#   'GCH1',
#   'SDC4',
#   'SLC22A4',
#   'MEIS2',
#   'SHQ1',
#   'BHLHE41',
#   'GAS1',
#   'HES1',
#   'TRIM2',
#   'ASPN',
#   'KRT18',
#   'EFNB2',
#   'TMC5',
#   'FAM60A',
#   'ZNF238',
#   'RCAN1',
#   'SCG2',
#   'MYO1B',
#   'GPNMB',
#   'SLC4A4',
#   'DYRK3',
#   'FBXO3',
#   'FST',
#   'EML4',
#   'KRT5',
#   'C3ORF14',
#   'MMP11',
#   'TBC1D8',
#   'MDK',
#   'SET',
#   'CYP1B1',
#   'PNO1',
#   'BBOX1',
#   'ELL2',
#   'ARF6',
#   'CAST',
#   'YWHAB',
#   'TSEN2',
#   'FGF13',
#   'DUSP4',
#   'DUSP3',
#   'PSMA7',
#   'P4HTM',
#   'H1F0',
#   'CSTA',
#   'C6ORF62',
#   'IL6R',
#   'TCEA1',
#   'LGALS8',
#   'SERPINF1',
#   'PRKAR1A',
#   'MXRA7',
#   'CITED2',
#   'LGALS3',
#   'DEGS1',
#   'TPSB2',
#   'AKIRIN1',
#   'ID4',
#   'EXOC5',
#   'ASNS',
#   'ID1',
#   'ADRB2',
#   'NKX3-1',
#   'OXTR',
#   'STEAP1',
#   'PLN',
#   'COCH',
#   'TMEM231',
#   'MAK16',
#   'IL8',
#   'CDC42',
#   'SEPP1',
#   'MYCL1',
#   'RPS11',
#   'WT1',
#   'DKK3',
#   'INSR',
#   'SOX9',
#   'RBMS1',
#   'RIPK4',
#   'SLC5A6',
#   'EDNRA',
#   'NIP7',
#   'ELF3',
#   'TMEM158',
#   'SHC1',
#   'CRABP1',
#   'RAB31',
#   'SIK1',
#   'CPNE3',
#   'TFAP2C',
#   'TFAP2B',
#   'OPHN1',
#   'ETS2',
#   'PEG10',
#   'TF',
#   'JAG1',
#   'AQP3',
#   'NR3C1',
#   'GREM1',
#   'ITGB5',
#   'HEATR1',
#   'CD44',
#   'C21ORF59',
#   'PRKCD',
#   'RTN2',
#   'TMX4',
#   'NEFH',
#   'TNC',
#   'ST6GALNAC5',
#   'CTSG',
#   'SNRPE',
#   'TARP',
#   'CRABP2',
#   'RPL38',
#   'PER2',
#   'SLC16A1',
#   'SNAPC1',
#   'IER2',
#   'DKK1',
#   'CDH11',
#   'PTPRC',
#   'CANT1',
#   'ABCC4',
#   'CD177',
#   'AHCY',
#   'BZW1',
#   'FOLR1',
#   'MMP1'],
#  'ASG001_MCF7_6H:BRD-K71879491-001-17-6:10': ['CD74',
#   'FXYD5',
#   'TMOD1',
#   'CLC',
#   'RAB4A',
#   'LYPLA1',
#   'MLEC',
#   'CPD',
#   'GSTA1',
#   'NQO1',
#   'IGKC',
#   'SULF1',
#   'FBLN1',
#   'CERS6',
#   'PPP1R3C',
#   'CITED2',
#   'SELENBP1',
#   'ACSM3',
#   'TRIM16',
#   'DHRS3',
#   'LYZ',
#   'MAP3K5',
#   'ZC3H15',
#   'SRPX2',
#   'HBD',
#   'CEACAM5',
#   'MYC',
#   'C13ORF15',
#   'CBLB',
#   'PRKAG2',
#   'PIK3R1',
#   'COG2',
#   'TSC22D3',
#   'HLA-DRB1',
#   'ATP1B1',
#   'PEX11A',
#   'POSTN',
#   'PER1',
#   'TPR',
#   'GATA6',
#   'SERPINB3',
#   'HBB',
#   'GATA2',
#   'TBXA2R',
#   'H2AFV',
#   'VEGFA',
#   'FN1',
#   'UCKL1',
#   'SLC2A1',
#   'OLFM4',
#   'LXN',
#   'NETO2',
#   'DLEU1',
#   'CCL5',
#   'SKAP2',
#   'QSOX1',
#   'PPOX',
#   'PRG2',
#   'KLHDC2',
#   'SERPINE1',
#   'XIST',
#   'SRSF7',
#   'APOE',
#   'NT5E',
#   'HOXA5',
#   'ABP1',
#   'CD9',
#   'HOXB2',
#   'HOXA4',
#   'LSR',
#   'SCNN1A',
#   'ANXA10',
#   'CLDN3',
#   'B4GALT5',
#   'UAP1',
#   'ATP1A1',
#   'EFEMP1',
#   'IGL@',
#   'CD164',
#   'HOXB6',
#   'HOXB7',
#   'PRKCD',
#   'IGFBP3',
#   'IGFBP6',
#   'VEGFC',
#   'IGFBP5',
#   'ITPR1',
#   'PTPN4',
#   'EPAS1',
#   'ABCG2',
#   'LRIG1',
#   'PLSCR1',
#   'MPO',
#   'SLC3A1',
#   'SDC4',
#   'RBPMS',
#   'TNFAIP2',
#   'MEIS2',
#   'PFN2',
#   'MGP',
#   'KRT13',
#   'HES1',
#   'WNT5A',
#   'NVL',
#   'CRIP1',
#   'CRIP2',
#   'EFNB2',
#   'SH3YL1',
#   'NUP133',
#   'CYP4B1',
#   'SMAD3',
#   'ALDH3A1',
#   'KRT7',
#   'MAPK13',
#   'SRGN',
#   'PTGER3',
#   'GPRC5A',
#   'IMP3',
#   'AKR1C3',
#   'NCOA3',
#   'AKR1B10',
#   'CYP1B1',
#   'ZBTB16',
#   'MECOM',
#   'ALCAM',
#   'SMC3',
#   'NR2F6',
#   'MRPS31',
#   'TPM2',
#   'PRPF40A',
#   'CIB1',
#   'S100A9',
#   'TSEN2',
#   'TM9SF3',
#   'DUSP4',
#   'DUSP6',
#   'RAB15',
#   'S100A8',
#   'EPB41L1',
#   'TGFBR2',
#   'ZBED2',
#   'LAMA3',
#   'TCEA2',
#   'SPARCL1',
#   'ENO2',
#   'TPD52L2',
#   'NOL8',
#   'LOC728855',
#   'TPD52L1',
#   'MUC5AC',
#   'CLU',
#   'HEBP2',
#   'LGALS4',
#   'BDKRB2',
#   'GALNT12',
#   'SFRP4',
#   'TLK2',
#   'RARRES3',
#   'RARRES1',
#   'HOXA7',
#   'BASP1',
#   'SOX9',
#   'NMB',
#   'EREG',
#   'HOXA1',
#   'GDPD5',
#   'HLA-DPA1',
#   'PLN',
#   'PSCA',
#   'CFD',
#   'ASAP2',
#   'NMI',
#   'DTX4',
#   'UFM1',
#   'S100P',
#   'HOXB5',
#   'NRIP1',
#   'FOXO3',
#   'MYBL1',
#   'TSKU',
#   'ATP11B',
#   'CMAHP',
#   'ELF3',
#   'NRIP3',
#   'ALDH1A3',
#   'LOXL1',
#   'HLA-DRA',
#   'RAP1GAP',
#   'DDX10',
#   'PLOD2',
#   'KCNK5',
#   'GCLC',
#   'TM4SF4',
#   'KCNK3',
#   'RGS2',
#   'TG',
#   'PIAS1',
#   'KRT20',
#   'PDE2A',
#   'CPT1A',
#   'ANXA3',
#   'PDGFD',
#   'LTBP2',
#   'LTBP1',
#   'DDX17',
#   'CDC42EP3',
#   'CD44',
#   'TMPRSS4',
#   'CA12',
#   'PLAU',
#   'MAN1C1',
#   'ALDOC',
#   'CD24',
#   'PBX1',
#   'TRIM2',
#   'IPO13',
#   'CRABP2',
#   'RHCG',
#   'PNP',
#   'SLC16A3',
#   'BAMBI',
#   'EZR',
#   'TESC',
#   'BOLA1',
#   'SLIRP',
#   'CAMK2N1',
#   'ABCC3'],
#  'HOG002_A549_6H:BRD-K71879491-001-22-6:0.1234': ['CD74',
#   'NIP7',
#   'PCK1',
#   'TMOD1',
#   'PROM1',
#   'LAT2',
#   'PPP2R3C',
#   'PLK2',
#   'LRRC16A',
#   'CPE',
#   'CD36',
#   'PRR5',
#   'MYL4',
#   'OAT',
#   'GPM6B',
#   'ASS1',
#   'ADIPOQ',
#   'CSGALNACT1',
#   'FAM50B',
#   'C1ORF115',
#   'ACSM3',
#   'VOPP1',
#   'LYZ',
#   'PSD3',
#   'INHBB',
#   'DEFA4',
#   'MAGI2',
#   'SC5DL',
#   'CDH1',
#   'CUL5',
#   'PDZRN3',
#   'RNASE1',
#   'PLCB1',
#   'LEFTY2',
#   'CTSG',
#   'RBP1',
#   'FLRT2',
#   'RBP4',
#   'KLK6',
#   'CADPS2',
#   'NME5',
#   'WDTC1',
#   'SLC4A4',
#   'SLC2A5',
#   'KIF5C',
#   'ARMCX1',
#   'TFPI2',
#   'MSRA',
#   'PTGS1',
#   'PLTP',
#   'TMEM14B',
#   'GRB7',
#   'FKBP1A',
#   'ACE2',
#   'CYTIP',
#   'CHAC1',
#   'PRKCI',
#   'NFATC3',
#   'ANKRD57',
#   'TSPYL5',
#   'HP',
#   'GAPDH',
#   'ITGA7',
#   'PPOX',
#   'PRG2',
#   'TRIB2',
#   'CHL1',
#   'SAMSN1',
#   'MAPKAPK5',
#   'SEPT6',
#   'DPEP1',
#   'LCN2',
#   'GAP43',
#   'MCTP1',
#   'SCD',
#   'MGAM',
#   'PPM1H',
#   'PLEKHB1',
#   'GUCY1A3',
#   'FBXL12',
#   'C1ORF54',
#   'B4GALT1',
#   'CEACAM8',
#   'CAMP',
#   'B4GALT5',
#   'PDLIM4',
#   'SORL1',
#   'G0S2',
#   'XPOT',
#   'MDK',
#   'CPA3',
#   'NUDT4',
#   'ELTD1',
#   'HIST1H2BG',
#   'CYTL1',
#   'POLR2I',
#   'ZBTB20',
#   'STRN3',
#   'ABCG2',
#   'ARG2',
#   'RBPMS',
#   'SLC22A4',
#   'MAOB',
#   'GPX3',
#   'CES2',
#   'PDZD2',
#   'SNCA',
#   'DCUN1D4',
#   'MINPP1',
#   'EEF1E1',
#   'MSMO1',
#   'CLDN10',
#   'EAF2',
#   'SMAD1',
#   'RFC2',
#   'FABP7',
#   'FABP4',
#   'PRKAR2B',
#   'FST',
#   'ATP5L',
#   'GSTA1',
#   'NES',
#   'NDP',
#   'GPRC5B',
#   'HMBS',
#   'QPRT',
#   'CYP1B1',
#   'FZD5',
#   'SNX10',
#   'LAPTM4B',
#   'SCRG1',
#   'ARPP19',
#   'S100A9',
#   'S100A8',
#   'OBSL1',
#   'TUBB2B',
#   'S100A1',
#   'LSM14A',
#   'KDR',
#   'CMAHP',
#   'ELN',
#   'PFDN4',
#   'APRT',
#   'TCFL5',
#   'C6ORF62',
#   'MCAM',
#   'CLC',
#   'PLA2G2A',
#   'CCND2',
#   'SERPINF1',
#   'VCAM1',
#   'BBX',
#   'CLU',
#   'CP',
#   'HIST1H1C',
#   'GLB1L2',
#   'F8',
#   'PIP5K1B',
#   'EMX2',
#   'ASNS',
#   'PAIP1',
#   'KIAA1199',
#   'STX16',
#   'COBL',
#   'PLN',
#   'TMEM231',
#   'ASAP2',
#   'KIF20A',
#   'SEPP1',
#   'RPS11',
#   'PCOLCE2',
#   'PDZK1IP1',
#   'ST6GAL1',
#   'BPI',
#   'SLC7A11',
#   'NFYB',
#   'PRSS2',
#   'BHMT2',
#   'RPA3',
#   'LEPREL1',
#   'SORBS1',
#   'DIRAS2',
#   'PEG3',
#   'MEF2C',
#   'ANKRD6',
#   'NDN',
#   'FAM149A',
#   'RGL1',
#   'ATP13A3',
#   'TM4SF1',
#   'ADCK3',
#   'GPR126',
#   'RGS5',
#   'SLC12A7',
#   'DNAJC12',
#   'LBP',
#   'LPCAT1',
#   'TF',
#   'PRUNE2',
#   'TCF4',
#   'ENPEP',
#   'DNMT3B',
#   'ESRRG',
#   'RAC2',
#   'PTPRZ1',
#   'MMP9',
#   'ADAT1',
#   'ZNF302',
#   'MAN1C1',
#   'RHOBTB3',
#   'ATP2A3',
#   'EMCN',
#   'CHST11',
#   'SEC22B',
#   'CFI',
#   'CA2',
#   'CALR',
#   'NRIP1',
#   'ROCK2',
#   'TFDP2',
#   'MBD4',
#   'ANK2',
#   'LPL',
#   'PTPRC',
#   'PDK4',
#   'PLAC8',
#   'ZNF652',
#   'LTF']}

# %%
DrOI_disease_up_signatures
# Out:
# {'BRD-K82255054': {'CPD003_PC3_6H:BRD-K82255054-001-11-8:10': ['TAP1',
#    'PTGS2',
#    'CD52',
#    'PCK1',
#    'TIMP2',
#    'GHR',
#    'TUSC3',
#    'GNPTAB',
#    'HSPA8',
#    'FADS1',
#    'HIPK1',
#    'FBP1',
#    'LEPROT',
#    'LYPD1',
#    'FRY',
#    'CPM',
#    'SFTPB',
#    'SPG20',
#    'SFTPC',
#    'EML3',
#    'ACAT2',
#    'CCL5',
#    'FGR',
#    'MICAL2',
#    'CDH1',
#    'IRAK3',
#    'WEE1',
#    'CDH2',
#    'MSMB',
#    'CBLB',
#    'SLC38A6',
#    'AQP3',
#    'TRHDE',
#    'RNASE6',
#    'IDH1',
#    'TPSB2',
#    'CGRRF1',
#    'BAZ1A',
#    'PHLDA1',
#    'STK3',
#    'DHX29',
#    'GATA6',
#    'RFNG',
#    'TMEM100',
#    'RNF19B',
#    'TNS1',
#    'PDE8B',
#    'KRAS',
#    'BRP44',
#    'ADCY1',
#    'CNN3',
#    'PLD3',
#    'CXCL9',
#    'TRAPPC3',
#    'SLC2A3',
#    'TCF7L2',
#    'AHR',
#    'ENC1',
#    'CCL19',
#    'PID1',
#    'PAK1',
#    'TNFSF13',
#    'ATP6V1D',
#    'CD1E',
#    'DMD',
#    'PLCB1',
#    'CRELD2',
#    'DES',
#    'SPON1',
#    'NDNF',
#    'WIF1',
#    'PTGDS',
#    'EDNRB',
#    'KLHDC2',
#    'IL1R1',
#    'NEK7',
#    'SMURF2',
#    'TUBA1A',
#    'NT5E',
#    'SLCO4C1',
#    'PSMG1',
#    'TNS3',
#    'MT1E',
#    'MT1F',
#    'SMC1A',
#    'TSPYL5',
#    'IGF1',
#    'ATP1A1',
#    'OXTR',
#    'ACAP1',
#    'IGFBP7',
#    'DYNC1LI2',
#    'CNIH',
#    'MT1P2',
#    'PDGFC',
#    'TMEM14B',
#    'QKI',
#    'IL7R',
#    'CDC42EP4',
#    'BCL2A1',
#    'LRRC17',
#    'SDC2',
#    'SLC24A3',
#    'FBXO34',
#    'MELK',
#    'MAOA',
#    'MGP',
#    'KRT13',
#    'ANPEP',
#    'MSLN',
#    'ITGAE',
#    'KRT18',
#    'CD74',
#    'ACP5',
#    'RAD23B',
#    'ZNF331',
#    'CCDC47',
#    'SMS',
#    'CYP4B1',
#    'CD4',
#    'PRKAR2B',
#    'AKAP13',
#    'SRGN',
#    'KIAA0101',
#    'DOCK10',
#    'CD9',
#    'DRAM1',
#    'PHTF2',
#    'GREB1',
#    'TNPO1',
#    'MPZL2',
#    'SEC23A',
#    'LAPTM4B',
#    'TPM2',
#    'PRPF40A',
#    'TPSAB1',
#    'PSMA2',
#    'CAST',
#    'FBXO21',
#    'FHL1',
#    'ICAM3',
#    'ICAM1',
#    'TCF21',
#    'GREM1',
#    'TM9SF3',
#    'SEC22B',
#    'ARL6IP5',
#    'CSTA',
#    'C6ORF62',
#    'HMGA1',
#    'LDLR',
#    'SERPINF1',
#    'PRKAR1A',
#    'SFTPD',
#    'LGALS3',
#    'LGALS2',
#    'MNAT1',
#    'SLC27A3',
#    'METTL9',
#    'SEMA3C',
#    'SFRP1',
#    'ACPP',
#    'MAGEH1',
#    'SGK1',
#    'IL11',
#    'ACOX1',
#    'IL6',
#    'BASP1',
#    'NKX3-1',
#    'PRKACB',
#    'STEAP1',
#    'PLN',
#    'TRPV2',
#    'HAPLN1',
#    'NEU1',
#    'EFHD2',
#    'IL27RA',
#    'CD55',
#    'IGSF6',
#    'PCOLCE2',
#    'BMPR1A',
#    'HSPA1A',
#    'SLC5A3',
#    'EPS8',
#    'MAGEA3',
#    'ARHGAP6',
#    'FYB',
#    'SERPINA1',
#    'CEBPA',
#    'PRPS2',
#    'DPYD',
#    'UBQLN2',
#    'SPTSSA',
#    'HS3ST3A1',
#    'SULF1',
#    'MAGEA6',
#    'RGS4',
#    'SPINK2',
#    'LDHB',
#    'PCNA',
#    'NR3C1',
#    'MATN2',
#    'BEX1',
#    'NRGN',
#    'CDC42EP3',
#    'CD44',
#    'CD40',
#    'PLAT',
#    'CES1',
#    'MGAT2',
#    'GPC3',
#    'TNFRSF11B',
#    'DACH1',
#    'SCML1',
#    'PPAP2B',
#    'EAPP',
#    'CCNB2',
#    'PRKCI',
#    'SLC16A3',
#    'ABI1',
#    'NOTCH2',
#    'C3ORF64',
#    'TNIP1',
#    'G3BP1',
#    'CFP',
#    'WT1',
#    'MMP9',
#    'ABCC4',
#    'LAMP3',
#    'COL6A3',
#    'BCL6',
#    'SLC1A1',
#    'PITPNC1']}}

# %%
def drug_name_lookup(pert_id):
    drug_name = list(drug_and_perts_final[drug_and_perts_final["pert_id"] == list(DrOI_disease_up_signatures.keys())].Name)
    return drug_name

# %%
[
    { 'drug_name': drug_name_lookup(pert_id), 'sig_id': sig_id, "pert_id": pert_id, "up_genes": up_genes }
    for pert_id, obj in DrOI_disease_up_signatures.items()
    for sig_id, up_genes in obj.items()
]
# Out:
# [{'drug_name': ['PROPOFOL'],
#   'sig_id': 'CPD003_PC3_6H:BRD-K82255054-001-11-8:10',
#   'pert_id': 'BRD-K82255054',
#   'up_genes': ['TAP1',
#    'PTGS2',
#    'CD52',
#    'PCK1',
#    'TIMP2',
#    'GHR',
#    'TUSC3',
#    'GNPTAB',
#    'HSPA8',
#    'FADS1',
#    'HIPK1',
#    'FBP1',
#    'LEPROT',
#    'LYPD1',
#    'FRY',
#    'CPM',
#    'SFTPB',
#    'SPG20',
#    'SFTPC',
#    'EML3',
#    'ACAT2',
#    'CCL5',
#    'FGR',
#    'MICAL2',
#    'CDH1',
#    'IRAK3',
#    'WEE1',
#    'CDH2',
#    'MSMB',
#    'CBLB',
#    'SLC38A6',
#    'AQP3',
#    'TRHDE',
#    'RNASE6',
#    'IDH1',
#    'TPSB2',
#    'CGRRF1',
#    'BAZ1A',
#    'PHLDA1',
#    'STK3',
#    'DHX29',
#    'GATA6',
#    'RFNG',
#    'TMEM100',
#    'RNF19B',
#    'TNS1',
#    'PDE8B',
#    'KRAS',
#    'BRP44',
#    'ADCY1',
#    'CNN3',
#    'PLD3',
#    'CXCL9',
#    'TRAPPC3',
#    'SLC2A3',
#    'TCF7L2',
#    'AHR',
#    'ENC1',
#    'CCL19',
#    'PID1',
#    'PAK1',
#    'TNFSF13',
#    'ATP6V1D',
#    'CD1E',
#    'DMD',
#    'PLCB1',
#    'CRELD2',
#    'DES',
#    'SPON1',
#    'NDNF',
#    'WIF1',
#    'PTGDS',
#    'EDNRB',
#    'KLHDC2',
#    'IL1R1',
#    'NEK7',
#    'SMURF2',
#    'TUBA1A',
#    'NT5E',
#    'SLCO4C1',
#    'PSMG1',
#    'TNS3',
#    'MT1E',
#    'MT1F',
#    'SMC1A',
#    'TSPYL5',
#    'IGF1',
#    'ATP1A1',
#    'OXTR',
#    'ACAP1',
#    'IGFBP7',
#    'DYNC1LI2',
#    'CNIH',
#    'MT1P2',
#    'PDGFC',
#    'TMEM14B',
#    'QKI',
#    'IL7R',
#    'CDC42EP4',
#    'BCL2A1',
#    'LRRC17',
#    'SDC2',
#    'SLC24A3',
#    'FBXO34',
#    'MELK',
#    'MAOA',
#    'MGP',
#    'KRT13',
#    'ANPEP',
#    'MSLN',
#    'ITGAE',
#    'KRT18',
#    'CD74',
#    'ACP5',
#    'RAD23B',
#    'ZNF331',
#    'CCDC47',
#    'SMS',
#    'CYP4B1',
#    'CD4',
#    'PRKAR2B',
#    'AKAP13',
#    'SRGN',
#    'KIAA0101',
#    'DOCK10',
#    'CD9',
#    'DRAM1',
#    'PHTF2',
#    'GREB1',
#    'TNPO1',
#    'MPZL2',
#    'SEC23A',
#    'LAPTM4B',
#    'TPM2',
#    'PRPF40A',
#    'TPSAB1',
#    'PSMA2',
#    'CAST',
#    'FBXO21',
#    'FHL1',
#    'ICAM3',
#    'ICAM1',
#    'TCF21',
#    'GREM1',
#    'TM9SF3',
#    'SEC22B',
#    'ARL6IP5',
#    'CSTA',
#    'C6ORF62',
#    'HMGA1',
#    'LDLR',
#    'SERPINF1',
#    'PRKAR1A',
#    'SFTPD',
#    'LGALS3',
#    'LGALS2',
#    'MNAT1',
#    'SLC27A3',
#    'METTL9',
#    'SEMA3C',
#    'SFRP1',
#    'ACPP',
#    'MAGEH1',
#    'SGK1',
#    'IL11',
#    'ACOX1',
#    'IL6',
#    'BASP1',
#    'NKX3-1',
#    'PRKACB',
#    'STEAP1',
#    'PLN',
#    'TRPV2',
#    'HAPLN1',
#    'NEU1',
#    'EFHD2',
#    'IL27RA',
#    'CD55',
#    'IGSF6',
#    'PCOLCE2',
#    'BMPR1A',
#    'HSPA1A',
#    'SLC5A3',
#    'EPS8',
#    'MAGEA3',
#    'ARHGAP6',
#    'FYB',
#    'SERPINA1',
#    'CEBPA',
#    'PRPS2',
#    'DPYD',
#    'UBQLN2',
#    'SPTSSA',
#    'HS3ST3A1',
#    'SULF1',
#    'MAGEA6',
#    'RGS4',
#    'SPINK2',
#    'LDHB',
#    'PCNA',
#    'NR3C1',
#    'MATN2',
#    'BEX1',
#    'NRGN',
#    'CDC42EP3',
#    'CD44',
#    'CD40',
#    'PLAT',
#    'CES1',
#    'MGAT2',
#    'GPC3',
#    'TNFRSF11B',
#    'DACH1',
#    'SCML1',
#    'PPAP2B',
#    'EAPP',
#    'CCNB2',
#    'PRKCI',
#    'SLC16A3',
#    'ABI1',
#    'NOTCH2',
#    'C3ORF64',
#    'TNIP1',
#    'G3BP1',
#    'CFP',
#    'WT1',
#    'MMP9',
#    'ABCC4',
#    'LAMP3',
#    'COL6A3',
#    'BCL6',
#    'SLC1A1',
#    'PITPNC1']}]

# %%
drug_and_perts_final = pd.DataFrame()
for q in (L1000_reverse_pertids_flat):
    drug_and_perts_final = drug_and_perts_final.append(drug_and_perts[drug_and_perts["pert_id"] == q])

# %%
drug_and_perts[drug_and_perts["pert_id"] == q]
# Out:
#        Name        pert_id
# 0  PROPOFOL  BRD-K82255054

# %%
drug_and_perts_final
# Out:
#         Name        pert_id
# 0  MIDAZOLAM  BRD-K00532621
# 0   PROPOFOL  BRD-K82255054
# 0  MIDAZOLAM  BRD-K00532621
# 0   PROPOFOL  BRD-K82255054

# %%
## X2K API integration 

# Import modules
import http.client
import json

##### Function to run X2K
### Input: a Python list of gene symbols
### Output: a dictionary containing the results of X2K, ChEA, G2N, KEA.


def run_X2K(input_genes, options={}):
    # Open HTTP connection
    conn = http.client.HTTPConnection("amp.pharm.mssm.edu")

    # Set default options
    default_options = {'text-genes': '\n'.join(input_genes),
                       'included_organisms': 'both',
                       'TF-target gene background database used for enrichment': 'ChEA & ENCODE Consensus',
                       'sort transcription factors by': 'p-value',
                       'min_network_size': 10,
                       'number of top TFs': 10,
                       'path_length': 2,
                       'min_number_of_articles_supporting_interaction': 0,
                       'max_number_of_interactions_per_protein': 200,
                       'max_number_of_interactions_per_article': 100,
                       'enable_BioGRID': True,
                       'enable_IntAct': True,
                       'enable_MINT': True,
                       'enable_ppid': True,
                       'enable_Stelzl': True,
                       'kinase interactions to include': 'kea 2018',
                       'sort kinases by': 'p-value'}

    # Update options
    for key, value in options.items():
        if key in default_options.keys() and key != 'text-genes':
            default_options.update({key: value})

    # Get payload
    boundary = "----WebKitFormBoundary7MA4YWxkTrZu0gW"
    payload = ''.join(
        ['--' + boundary + '\r\nContent-Disposition: form-data; name=\"{key}\"\r\n\r\n{value}\r\n'.format(**locals())
         for key, value in default_options.items()]) + '--' + boundary + '--'

    # Get Headers
    headers = {
        'content-type': "multipart/form-data; boundary=" + boundary,
        'cache-control': "no-cache",
    }

    # Initialize connection
    conn.request("POST", "/X2K/api", payload, headers)

    # Get response
    res = conn.getresponse()

    # Read response
    data = res.read().decode('utf-8')

    # Convert to dictionary
    x2k_results = {key: json.loads(value) if key != 'input' else value for key, value in json.loads(data).items()}

    # Clean results
    x2k_results['ChEA'] = x2k_results['ChEA']['tfs']
    x2k_results['G2N'] = x2k_results['G2N']['network']
    x2k_results['KEA'] = x2k_results['KEA']['kinases']
    x2k_results['X2K'] = x2k_results['X2K']['network']

    # Return results
    return x2k_results

############################################################################################################################################################
#### L1000 DRUG X2K


### L1000 PRELOAD DATA DRUG CARD
with open ("L1000_up_lookup.json", 'r') as f:
    L1000_up_lookup = json.load(f)

with open ("L1000_down_lookup.json", 'r') as f:
    L1000_down_lookup = json.load(f)
    
metadata = pd.read_csv("L1000_metadata.csv")

### L1000 DRUG CARD DRUG INPUT
DrOI = "tretinoin" ## this will be the user input 

DrOI_df = metadata[metadata["pert_desc"] == DrOI]
DrOI_pert_ids = list(DrOI_df["pert_id"])

DrOI_up_signatures = {k: L1000_up_lookup[k] for k in (DrOI_pert_ids)}
DrOI_up_no_perts = {k: v for d in DrOI_up_signatures.values() for k, v in d.items()}
DrOI_up_drug_sigs = list(DrOI_up_no_perts.keys())

DrOI_down_signatures = {k: L1000_down_lookup[k] for k in (DrOI_pert_ids)}
DrOI_down_no_perts = {k: v for d in DrOI_down_signatures.values() for k, v in d.items()}
DrOI_down_drug_sigs = list(DrOI_down_no_perts.keys())

DrOI_all_sigs = set(DrOI_up_drug_sigs) & set (DrOI_down_drug_sigs)

for a in DrOI_all_sigs:
    L1000_up_json_file = DrOI_up_no_perts[a]
    L1000_down_json_file = DrOI_down_no_perts[a]
    
    ### X2k CODE
    L1000_X2K_up_genes = run_X2K(L1000_up_json_file)
    L1000_X2K_up_genes = L1000_X2K_up_genes["X2K"]
    L1000_X2K_up_genes_df = pd.DataFrame(L1000_X2K_up_genes['nodes'])
    filename_up = (a + "_X2K_up_genes.csv")
    #L1000_X2K_up_genes_df.to_csv(filename_up) # THIS IS THE FILE THEY SHOULD BE ABLE TO DOWNLOAD
    print(filename_up)

        #L1000 down genes
    L1000_X2K_down_genes = run_X2K(L1000_down_json_file)
    L1000_X2K_down_genes = L1000_X2K_down_genes["X2K"]
    L1000_X2K_down_genes_df = pd.DataFrame(L1000_X2K_down_genes['nodes'])
    filename_down = (a + "_X2K_down_genes.csv")
    #L1000_X2K_down_genes_df.to_csv(filename_down) # THIS IS THE FILE THEY SHOULD BE ABLE TO DOWNLOAD

    with open(a + "_L1000_up_sig.json", "w") as f:
        json.dump(L1000_up_json_file, f) # this is the json file
        #print("ups")
    with open(a + "_L1000_down_sig.json", "w") as f:
        json.dump(L1000_down_json_file, f) # this is the json file
        #print("downs")
